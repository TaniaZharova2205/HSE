# %% [raw]
# 3.1 (Вспоминаем, что такое numpy) (3 балла)
#
# 1.  (1 б.)
#
# Создайте с помощью np.random.randint numpy массив из 20-ти рандомных чисел. Посчитайте с помощью методов numpy и выведите на экран:
#
# среднее значение в массиве
# минимальное значение в массиве
# максимальное значение в массиве
# индекс минимального элемента в массиве
# 2.  (1 б.)Создайте два numpy массива: в первом должны быть четные числа от 2 до 14 включительно, а во втором — числа 7, 11, 17, 18, 23, 30, 45.
#
# Сложите массивы и возведите элементы получившегося массива в квадрат
# Выведите все элементы из первого массива, которые стоят на тех местах, где элементы второго массива больше 12 и дают остаток 3 при делении на 5.
# Для первого массива найдите остатки от деления на 2, а для второго — на 3.
# 3.  (1 б.)
#
# Сгенерируйте рандомный массив b размера 3x1.
# Сгенерируйте матрицу С размера 3x3.
# Решите систему Cx = b с помощью numpy.linalg.solve
# Подумайте/погуглите, в каком случае numpy.linalg.solve вернет ошибку LinAlgError. Воспроизведите этот случай.

# %%
import numpy as np
a = np.random.randint(100, size = 20)
print("Среднее значение в массиве a:", np.mean(a))
print("Минимальное значение в массиве a:", np.min(a))
print("Максимальное значение в массиве a:", np.max(a))
print("Индекс минимального элемента в массиве a:", a.argmin())
# Out:
# Среднее значение в массиве a: 54.4
# Минимальное значение в массиве a: 8
# Максимальное значение в массиве a: 97
# Индекс минимального элемента в массиве a: 5

# %%
b = np.arange(2, 15, 2)
c = np.array([7, 11, 17, 18, 23, 30, 45])
print("Массив b:", b)
print("Массив c:", c)
print("Возведённая в квадрат сумма массивов b и c:", (b + c)**2)
print("Элементы из первого массива, которые стоят на тех местах, где элементы второго массива больше 12 и дают остаток 3 при делении на 5:", b[(c > 12) & (c%5==3)])
print("Остаток от деления массива b на 2:", b%2)
print("Остаток от деления массива с на 3:", c%3)
# Out:
# Массив b: [ 2  4  6  8 10 12 14]
# Массив c: [ 7 11 17 18 23 30 45]
# Возведённая в квадрат сумма массивов b и c: [  81  225  529  676 1089 1764 3481]
# Элементы из первого массива, которые стоят на тех местах, где элементы второго массива больше 12 и дают остаток 3 при делении на 5: [ 8 10]
# Остаток от деления массива b на 2: [0 0 0 0 0 0 0]
# Остаток от деления массива с на 3: [1 2 2 0 2 0 0]

# %%
b = np.random.rand(3, 1)
c = np.random.rand(3, 3)
print("Матрица b:", b)
print("Матрица c:", c)
print("Решение x:", np.linalg.solve(c, b))
print("Ошибка LinAlgError, так как количество столбцов в b не совпадают с количеством строк в c") 
print(np.linalg.solve(b, c))
# Out:
# Матрица b: [[0.69028251]
#  [0.65552893]
#  [0.22394563]]
# Матрица c: [[0.6465293  0.6265367  0.04322675]
#  [0.59857065 0.73341143 0.25823652]
#  [0.40438929 0.21464878 0.82815899]]
# Решение x: [[ 0.72853155]
#  [ 0.36233064]
#  [-0.1792392 ]]
# Ошибка LinAlgError, так как количество столбцов в b не совпадают с количеством строк в c
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[302], line 7
#       5 print("Решение x:", np.linalg.solve(c, b))
#       6 print("Ошибка LinAlgError, так как количество столбцов в b не совпадают с количеством строк в c")
# ----> 7 print(np.linalg.solve(b, c))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\linalg\_linalg.py:399, in solve(a, b)
#     397 a, _ = _makearray(a)
#     398 _assert_stacked_2d(a)
# --> 399 _assert_stacked_square(a)
#     400 b, wrap = _makearray(b)
#     401 t, result_t = _commonType(a, b)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\linalg\_linalg.py:202, in _assert_stacked_square(*arrays)
#     200 m, n = a.shape[-2:]
#     201 if m != n:
# --> 202     raise LinAlgError('Last 2 dimensions of the array must be square')
#
# LinAlgError: Last 2 dimensions of the array must be square

# %% [raw]
# 3.2 (12 баллов)
#
# Сравните производительность операций умножения матриц с использованием библиотеки NumPy и стандартных списков Python для матриц размером от 2x2 до 100x100.
#
# Сгенерируйте две матрицы A и B случайного размера от nxn, заполненные случайными целыми числами от 1 до 50. (1 балл)
# Используя библиотеку NumPy, выполните умножение матриц A и B. Измерьте время выполнения операции. (1 балл)
# Реализуйте функцию для умножения матриц с помощью стандартных списков Python. Измерьте время выполнения этой операции. (2 балла)
# Сделайте вышеперечисленные пункты для n=2,...100. (3 балла)
# Для какого-нибудь n проверьте, что результаты совпадают. (1 балл)
# Постройте график, где по оси X будет размер матрицы, по оси Y - время выполнения операции. Постройте два графика (для numpy и для стандартных списков) (4 балла)

# %%
import time 
import matplotlib.pyplot as plt

#функция умножения матриц list
def dot_AB(n, A, B): 
    A_dot_B = [[0 for i in range(n)] for i in range(n)]
    for i in range(n):
        for j in range(n):
            for k in range(n):
                A_dot_B[i][j] += A[i][k]*B[k][j]
    return A_dot_B

#время выполнения numpy
def measure_numpy_multiplication(A,B):
    time_start = time.time()
    A.dot(B)
    return time.time() - time_start

#время выполнения list
def measure_list_multiplication(n,A,B):
    time_start = time.time()
    dot_AB(n, A, B)
    return time.time() - time_start

#отрисовка графиков
def graph(x, time_numpy, time_list):
    
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(25, 6))
    
    axes[0].plot(x, time_numpy, color="#00FFFF", label = "numpy")
    axes[0].plot(x, time_list, color="#FF69B4", label = "списки")
    axes[0].set_xlabel("Размер матрицы")
    axes[0].set_ylabel("Время выполнения умножения матриц")
    axes[0].legend()
    
    axes[1].plot(x, time_numpy, color="#00FFFF", label = "numpy")
    axes[1].set_xlabel("Размер матрицы")
    axes[1].set_ylabel("Время выполнения умножения матриц с помощью numpy")
    
    axes[2].plot(x, time_list, color="#FF69B4", label = "списки")
    axes[2].set_xlabel("Размер матрицы")
    axes[2].set_ylabel("Время выполнения умножения матриц с помощью списков")

n = np.arange(2,101)
time_numpy = []
time_list = []
for i in n:
    A = np.random.randint(1, 51, (i, i))
    B = np.random.randint(1, 51, (i, i))

    A_list = A.tolist()
    B_list = B.tolist()
    
    time_numpy.append(measure_numpy_multiplication(A,B))
    time_list.append(measure_list_multiplication(i, A_list,B_list))

    #проверка на совпадение результатов
    if i == 88:
        print(np.array_equal(A.dot(B), np.array(dot_AB(i, A, B))))

graph(n, time_numpy, time_list)
# Out:
# True

# %% [raw]
# Вам предлагает проанализировать датасет с Data - вакансиями. Скачайте его https://disk.yandex.ru/d/QUa3pCKVk48cAQ и считайте с помощью pd.read_csv.
#
# Выведите первые 5 строк датасете. Примените к датасету методы info и describe (1)
# Сколько в датасете строк и столбцов? (1)
# Есть ли в датасете пропуски? (1)
# Есть в датасете полные дубли? Если да, удалите их. (1)
# Сколько уникальных значений у переменной professional_roles? (1)
# Сколько в датасете вакансий, не требующих опыта? (2)
# Какое среднее количество навыков в вакансии? (переменная key_skills) (2)
# Какие валюты (ключ currency в поле salary) используются для заработной платы? Создайте столбец currency. (2)
# Какая компания лидирует по количеству вакансий? (2)
# Какая компания лидирует по количеству вакансий с указанием заработной платы? (2)
# Создайте столбец salary_num. Рассчитайте его, используя столбец salary. Если в это столбце указана вилка зарплаты, используйте среднее значение между from и to. (2)
# Создайте столбец is_python_requirement, который принимает значение 1, если в key_skills присутствует python (учитывайте написание в любом регистре). Какой процент вакансий требует знания python? (2)
# Сгруппируйте по столбцам experience, schedule, employment, is_python. Найдите по каждой группе количество опубликованных вакансий, среднюю заработную плату, количество компаний, которые опубликовали вакансии. (3)
# Сделайте сводную таблицу (pd.pivot_table) по компаниям: название компании, количество вакансий, средняя заработная плата среди вакансий с указанием зарплаты в рублях. (3)
# Какие скиллы чаще всего требуются? Выведите топ-10 требуемых скиллов. (3)
# Постройте гистограмму распределения зарплаты среди вакансий в рублях. (2)
# Постройте boxplot зарплаты с группировкой по полю experience (2)
# Попробуйте ответить на какой-нибудь вопрос по данным, не заданный ранее. Никак не ограничиваем вашу фантазию (3)

# %%
import pandas as pd
df = pd.read_csv('vacancies.csv').drop('Unnamed: 0', axis=1)

# %% [raw]
# Выведите первые 5 строк датасете. Примените к датасету методы info и describe (1)

# %%
df.head()
# Out:
#                                        position_name  \
# 0                               Data Scientist Авито
# 1                                       Data analyst
# 2                         Data Engineer/Data Analyst
# 3                      Стажер в направление Big Data
# 4  Data Marketing Manager / Маркетолог по анализу...
#
#                                      employer_name     area  \
# 0                                     Changellenge   Москва
# 1  Публичная Компания «Freedom Finance Global PLC»   Алматы
# 2                                         IMANTECH  Ташкент
# 3                                               T2   Москва
# 4                                 Procter & Gamble   Алматы
#
#            experience       schedule        employment  \
# 0  От 1 года до 3 лет    Полный день  Полная занятость
# 1  От 1 года до 3 лет    Полный день  Полная занятость
# 2           Нет опыта  Гибкий график  Полная занятость
# 3           Нет опыта    Полный день  Полная занятость
# 4  От 1 года до 3 лет    Полный день  Полная занятость
#
#              professional_roles  \
# 0                        Другое
# 1  BI-аналитик, аналитик данных
# 2  BI-аналитик, аналитик данных
# 3  BI-аналитик, аналитик данных
# 4                        Другое
#
#                                               salary  \
# 0  {'from': 255000, 'to': 490000, 'currency': 'RU...
# 1  {'from': 800000, 'to': 'null', 'currency': 'KZ...
# 2                                                NaN
# 3                                                NaN
# 4  {'from': 950000, 'to': 'null', 'currency': 'KZ...
#
#                                          description  \
# 0  <p>В наших командах разрабатывают эффективные ...
# 1  <p><strong>Обязанности</strong></p><ul><li>Изв...
# 2  <p><strong>About Us:</strong> Welcome to <stro...
# 3  <strong>Что нужно делать:</strong> <ul> <li>Со...
# 4  <p><strong>Найм в ТОО «Проктер энд Гэмбл Казах...
#
#                                           key_skills
# 0                                                 []
# 1                                                 []
# 2  ['SQL', 'Визуализация данных', 'Python', 'Powe...
# 3                                                 []
# 4     ['Английский язык', 'Аналитический склад ума']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1527 entries, 0 to 1526
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   position_name       1527 non-null   object
#  1   employer_name       1527 non-null   object
#  2   area                1527 non-null   object
#  3   experience          1527 non-null   object
#  4   schedule            1527 non-null   object
#  5   employment          1527 non-null   object
#  6   professional_roles  1527 non-null   object
#  7   salary              220 non-null    object
#  8   description         1527 non-null   object
#  9   key_skills          1527 non-null   object
# dtypes: object(10)
# memory usage: 119.4+ KB

# %%
df.describe()
# Out:
#         position_name employer_name    area     experience     schedule  \
# count            1527          1527    1527           1527         1527
# unique            793           524     102              4            5
# top     Data Engineer          СБЕР  Москва  От 3 до 6 лет  Полный день
# freq              126           146     912            724         1098
#
#               employment professional_roles  \
# count               1527               1527
# unique                 4                 36
# top     Полная занятость     Дата-сайентист
# freq                1464                464
#
#                                                    salary  \
# count                                                 220
# unique                                                130
# top     {'from': 100000, 'to': 110000, 'currency': 'RU...
# freq                                                   20
#
#                                               description key_skills
# count                                                1527       1527
# unique                                               1232        653
# top     <p>Striving to gain market-oriented knowledge ...         []
# freq                                                   46        607

# %%
df.describe(include = 'object')
# Out:
#         position_name employer_name    area     experience     schedule  \
# count            1527          1527    1527           1527         1527
# unique            793           524     102              4            5
# top     Data Engineer          СБЕР  Москва  От 3 до 6 лет  Полный день
# freq              126           146     912            724         1098
#
#               employment professional_roles  \
# count               1527               1527
# unique                 4                 36
# top     Полная занятость     Дата-сайентист
# freq                1464                464
#
#                                                    salary  \
# count                                                 220
# unique                                                130
# top     {'from': 100000, 'to': 110000, 'currency': 'RU...
# freq                                                   20
#
#                                               description key_skills
# count                                                1527       1527
# unique                                               1232        653
# top     <p>Striving to gain market-oriented knowledge ...         []
# freq                                                   46        607

# %% [raw]
# Сколько в датасете строк и столбцов?

# %%
df.shape
# Out:
# (1527, 10)

# %% [markdown]
# Есть ли в датасете пропуски? (1)

# %%
print(df.isnull().any(), '\n')
print(df.isnull().any().any())
# Out:
# position_name         False
# employer_name         False
# area                  False
# experience            False
# schedule              False
# employment            False
# professional_roles    False
# salary                 True
# description           False
# key_skills            False
# dtype: bool
#
# True

# %% [raw]
# Есть в датасете полные дубли? Если да, удалите их. (1)

# %%
duplicates = df.duplicated()
num_duplicates = duplicates.sum()
print(num_duplicates)#146 полных дубликатов
df.drop_duplicates()
# Out:
# 146
#                                           position_name  \
# 0                                  Data Scientist Авито
# 1                                          Data analyst
# 2                            Data Engineer/Data Analyst
# 3                         Стажер в направление Big Data
# 4     Data Marketing Manager / Маркетолог по анализу...
# ...                                                 ...
# 1522            Senior Data Scientist в b2c направление
# 1523                              Data analyst (Senior)
# 1524                                Senior Data Analyst
# 1525                             TeamLead Data Engineer
# 1526            Senior Python Developer (Data Platform)
#
#                                         employer_name     area  \
# 0                                        Changellenge   Москва
# 1     Публичная Компания «Freedom Finance Global PLC»   Алматы
# 2                                            IMANTECH  Ташкент
# 3                                                  T2   Москва
# 4                                    Procter & Gamble   Алматы
# ...                                               ...      ...
# 1522                                       HeadHunter   Москва
# 1523                                              Иви   Москва
# 1524                Autodoc Group (Автодок Казахстан)   Алматы
# 1525                                       HeadHunter   Москва
# 1526                                          Mindbox   Москва
#
#               experience       schedule        employment  \
# 0     От 1 года до 3 лет    Полный день  Полная занятость
# 1     От 1 года до 3 лет    Полный день  Полная занятость
# 2              Нет опыта  Гибкий график  Полная занятость
# 3              Нет опыта    Полный день  Полная занятость
# 4     От 1 года до 3 лет    Полный день  Полная занятость
# ...                  ...            ...               ...
# 1522       От 3 до 6 лет  Гибкий график  Полная занятость
# 1523       От 3 до 6 лет    Полный день  Полная занятость
# 1524       От 3 до 6 лет    Полный день  Полная занятость
# 1525       От 3 до 6 лет    Полный день  Полная занятость
# 1526       От 3 до 6 лет  Гибкий график  Полная занятость
#
#                 professional_roles  \
# 0                           Другое
# 1     BI-аналитик, аналитик данных
# 2     BI-аналитик, аналитик данных
# 3     BI-аналитик, аналитик данных
# 4                           Другое
# ...                            ...
# 1522      Программист, разработчик
# 1523  BI-аналитик, аналитик данных
# 1524          Продуктовый аналитик
# 1525      Программист, разработчик
# 1526      Программист, разработчик
#
#                                                  salary  \
# 0     {'from': 255000, 'to': 490000, 'currency': 'RU...
# 1     {'from': 800000, 'to': 'null', 'currency': 'KZ...
# 2                                                   NaN
# 3                                                   NaN
# 4     {'from': 950000, 'to': 'null', 'currency': 'KZ...
# ...                                                 ...
# 1522                                                NaN
# 1523                                                NaN
# 1524                                                NaN
# 1525                                                NaN
# 1526                                                NaN
#
#                                             description  \
# 0     <p>В наших командах разрабатывают эффективные ...
# 1     <p><strong>Обязанности</strong></p><ul><li>Изв...
# 2     <p><strong>About Us:</strong> Welcome to <stro...
# 3     <strong>Что нужно делать:</strong> <ul> <li>Со...
# 4     <p><strong>Найм в ТОО «Проктер энд Гэмбл Казах...
# ...                                                 ...
# 1522  <p>Наша команда работает с соискательской функ...
# 1523  <p><strong>Иви — один из лидеров рынка онлайн-...
# 1524  <p>Company Description</p> <p>AUTODOC is a tec...
# 1525  <p><strong>Привет,</strong> <strong>на связи к...
# 1526  <p><strong>Mindbox</strong> — крупнейшая в Рос...
#
#                                              key_skills
# 0                                                    []
# 1                                                    []
# 2     ['SQL', 'Визуализация данных', 'Python', 'Powe...
# 3                                                    []
# 4        ['Английский язык', 'Аналитический склад ума']
# ...                                                 ...
# 1522  ['Python', 'Machine Learning', 'SQL', 'PyTorch...
# 1523                                                 []
# 1524                                                 []
# 1525  ['Python', 'Apache Airflow', 'Apache Cassandra...
# 1526  ['Python', 'PySpark', 'Airflow', 'Kafka', 'Del...
#
# [1381 rows x 10 columns]

# %%
df.fillna(0, inplace=True) #Заменяем пропуски на 0
df['salary'] = df['salary'].apply(lambda value: ast.literal_eval(value) if value!=0 else {})#преобразуем строку в словарь
df['key_skills'] = df['key_skills'].apply(lambda value: ast.literal_eval(value))#преобразуем строку в список

# %% [raw]
# Сколько уникальных значений у переменной professional_roles? (1)

# %%
df['professional_roles'].nunique()#36
# Out:
# 36

# %% [raw]
# Сколько в датасете вакансий, не требующих опыта? (2)

# %%
df[df['experience'] == 'Нет опыта'].shape[0]   #136
# Out:
# 136

# %% [raw]
# Какое среднее количество навыков в вакансии? (переменная key_skills) (2)

# %%
import ast
print(df['key_skills'].apply(lambda value: len(value)).mean())
# Out:
# 3.8749181401440733

# %% [raw]
# Какие валюты (ключ currency в поле salary) используются для заработной платы? Создайте столбец currency. (2)

# %%
df['currency'] = df['salary'].apply(lambda value: value['currency'] if value else 0)
df['currency'].head()
# Out:
# 0    RUR
# 1    KZT
# 2      0
# 3      0
# 4    KZT
# Name: currency, dtype: object

# %% [raw]
# Какая компания лидирует по количеству вакансий? (2)

# %%
count_vak = df.groupby(['employer_name'])['employer_name'].count().idxmax()
count_vak
# Out:
# 'СБЕР'

# %% [raw]
# Какая компания лидирует по количеству вакансий с указанием заработной платы? (2)

# %%
df[df['salary']!=dict()].groupby(['employer_name'])['employer_name'].count().idxmax()
# Out:
# 'Aston'

# %% [raw]
# Создайте столбец salary_num. Рассчитайте его, используя столбец salary. Если в это столбце указана вилка зарплаты,
# используйте среднее значение между from и to. (2)

# %%
def salary_num_function(value):
    if value == {}:
        return 0
    elif value['from']!='null' and value['to']!='null':
        return (value['to'] - value['from'])//2
    elif value['from']!='null':
        return value['from']
    elif value['to']!='null':
        return value['to']

df['salary_num'] = df['salary'].apply(salary_num_function)
df['salary_num'].head()
# Out:
# 0    117500
# 1    800000
# 2         0
# 3         0
# 4    950000
# Name: salary_num, dtype: int64

# %% [raw]
# Создайте столбец is_python_requirement, который принимает значение 1, если в key_skills присутствует python
# (учитывайте написание в любом регистре). Какой процент вакансий требует знания python? (2)

# %%
def is_python_requirement_function(x):
    for i in x:
        if i.lower() == 'python':
            return 1
    return 0
df['is_python_requirement'] = df['key_skills'].apply(is_python_requirement_function)
print(df[df['is_python_requirement']==1]['is_python_requirement'].count()*100/df.shape[0])
df.head()
# Out:
# 41.45383104125737
#                                        position_name  \
# 0                               Data Scientist Авито
# 1                                       Data analyst
# 2                         Data Engineer/Data Analyst
# 3                      Стажер в направление Big Data
# 4  Data Marketing Manager / Маркетолог по анализу...
#
#                                      employer_name     area  \
# 0                                     Changellenge   Москва
# 1  Публичная Компания «Freedom Finance Global PLC»   Алматы
# 2                                         IMANTECH  Ташкент
# 3                                               T2   Москва
# 4                                 Procter & Gamble   Алматы
#
#            experience       schedule        employment  \
# 0  От 1 года до 3 лет    Полный день  Полная занятость
# 1  От 1 года до 3 лет    Полный день  Полная занятость
# 2           Нет опыта  Гибкий график  Полная занятость
# 3           Нет опыта    Полный день  Полная занятость
# 4  От 1 года до 3 лет    Полный день  Полная занятость
#
#              professional_roles  \
# 0                        Другое
# 1  BI-аналитик, аналитик данных
# 2  BI-аналитик, аналитик данных
# 3  BI-аналитик, аналитик данных
# 4                        Другое
#
#                                               salary  \
# 0  {'from': 255000, 'to': 490000, 'currency': 'RU...
# 1  {'from': 800000, 'to': 'null', 'currency': 'KZ...
# 2                                                 {}
# 3                                                 {}
# 4  {'from': 950000, 'to': 'null', 'currency': 'KZ...
#
#                                          description  \
# 0  <p>В наших командах разрабатывают эффективные ...
# 1  <p><strong>Обязанности</strong></p><ul><li>Изв...
# 2  <p><strong>About Us:</strong> Welcome to <stro...
# 3  <strong>Что нужно делать:</strong> <ul> <li>Со...
# 4  <p><strong>Найм в ТОО «Проктер энд Гэмбл Казах...
#
#                                           key_skills currency  salary_num  \
# 0                                                 []      RUR      117500
# 1                                                 []      KZT      800000
# 2  [SQL, Визуализация данных, Python, Power BI, A...        0           0
# 3                                                 []        0           0
# 4         [Английский язык, Аналитический склад ума]      KZT      950000
#
#    is_python_requirement
# 0                      0
# 1                      0
# 2                      1
# 3                      0
# 4                      0

# %% [raw]
# Сгруппируйте по столбцам experience, schedule, employment, is_python. Найдите по каждой группе количество
# опубликованных вакансий, среднюю заработную плату, количество компаний, которые опубликовали вакансии. (3)

# %%
def salary_num_RUR(x):
    if x['currency'] == 'RUR':
        return x
    else:
        x['salary_num'] = 0
        return x

rur_salaries = df.apply(salary_num_RUR, axis=1)
rur_salaries.groupby(['experience', 'schedule', 'employment', 'is_python_requirement'], as_index=False).agg(
    count_vacancy=('experience', 'count'),
    salary_mean = ('salary_num', 'mean'),
    count_employer_name = ('employer_name', 'nunique')
)
# Out:
#             experience          schedule           employment  \
# 0          Более 6 лет     Гибкий график     Полная занятость
# 1          Более 6 лет     Гибкий график  Частичная занятость
# 2          Более 6 лет       Полный день     Полная занятость
# 3          Более 6 лет       Полный день     Полная занятость
# 4          Более 6 лет  Удаленная работа     Полная занятость
# 5          Более 6 лет  Удаленная работа     Полная занятость
# 6            Нет опыта     Гибкий график     Полная занятость
# 7            Нет опыта     Гибкий график           Стажировка
# 8            Нет опыта       Полный день     Полная занятость
# 9            Нет опыта       Полный день     Полная занятость
# 10           Нет опыта       Полный день           Стажировка
# 11           Нет опыта       Полный день           Стажировка
# 12           Нет опыта  Удаленная работа     Полная занятость
# 13           Нет опыта  Удаленная работа     Полная занятость
# 14           Нет опыта  Удаленная работа           Стажировка
# 15           Нет опыта  Удаленная работа           Стажировка
# 16  От 1 года до 3 лет    Вахтовый метод     Полная занятость
# 17  От 1 года до 3 лет     Гибкий график     Полная занятость
# 18  От 1 года до 3 лет     Гибкий график     Полная занятость
# 19  От 1 года до 3 лет     Гибкий график           Стажировка
# 20  От 1 года до 3 лет     Гибкий график  Частичная занятость
# 21  От 1 года до 3 лет       Полный день     Полная занятость
# 22  От 1 года до 3 лет       Полный день     Полная занятость
# 23  От 1 года до 3 лет    Сменный график     Полная занятость
# 24  От 1 года до 3 лет    Сменный график     Полная занятость
# 25  От 1 года до 3 лет    Сменный график  Частичная занятость
# 26  От 1 года до 3 лет  Удаленная работа     Полная занятость
# 27  От 1 года до 3 лет  Удаленная работа     Полная занятость
# 28  От 1 года до 3 лет  Удаленная работа  Частичная занятость
# 29  От 1 года до 3 лет  Удаленная работа  Частичная занятость
# 30       От 3 до 6 лет     Гибкий график     Полная занятость
# 31       От 3 до 6 лет     Гибкий график     Полная занятость
# 32       От 3 до 6 лет     Гибкий график     Проектная работа
# 33       От 3 до 6 лет       Полный день     Полная занятость
# 34       От 3 до 6 лет       Полный день     Полная занятость
# 35       От 3 до 6 лет       Полный день     Проектная работа
# 36       От 3 до 6 лет  Удаленная работа     Полная занятость
# 37       От 3 до 6 лет  Удаленная работа     Полная занятость
# 38       От 3 до 6 лет  Удаленная работа  Частичная занятость
# 39       От 3 до 6 лет  Удаленная работа  Частичная занятость
#
#     is_python_requirement  count_vacancy  salary_mean  count_employer_name
# 0                       0              4        0.000                    2
# 1                       0              1        0.000                    1
# 2                       0             49    23673.469                   30
# 3                       1             10        0.000                    9
# 4                       0             11    40909.091                    7
# 5                       1             12    51666.667                   10
# 6                       1              2    12500.000                    2
# 7                       1              3        0.000                    1
# 8                       0             26    11269.231                   17
# 9                       1             55     4000.000                    6
# 10                      0              7     9442.857                    4
# 11                      1              9        0.000                    3
# 12                      0              2        0.000                    2
# 13                      1              1        0.000                    1
# 14                      0              2        0.000                    2
# 15                      1             29     4310.345                    1
# 16                      0              1        0.000                    1
# 17                      0              6    20000.000                    4
# 18                      1             18    16666.667                   14
# 19                      0              1        0.000                    1
# 20                      1              2        0.000                    1
# 21                      0            292    14546.233                  132
# 22                      1            156    12660.256                  104
# 23                      0              2        0.000                    2
# 24                      1              1        0.000                    1
# 25                      0              1        0.000                    1
# 26                      0             51    21274.510                   36
# 27                      1             46    12282.609                   37
# 28                      0              1        0.000                    1
# 29                      1              2        0.000                    2
# 30                      0              9        0.000                    6
# 31                      1              7        0.000                    7
# 32                      0              1        0.000                    1
# 33                      0            320     4218.750                  132
# 34                      1            173    28190.173                  105
# 35                      1              1   250000.000                    1
# 36                      0            106    32287.736                   56
# 37                      1            104    27620.192                   63
# 38                      0              1    50000.000                    1
# 39                      1              2        0.000                    1

# %% [raw]
# Сделайте сводную таблицу (pd.pivot_table) по компаниям: название компании, количество вакансий, средняя заработная
# плата среди вакансий с указанием зарплаты в рублях. (3)

# %%
table_pivot = pd.pivot_table(rur_salaries,
               index = 'employer_name',
               values=['position_name', 'salary_num'],
               aggfunc={
                    'position_name': 'count',
                    'salary_num': 'mean'
                },
            )
table_pivot.rename(columns={'position_name': 'count_vacancy', 'salary_num': 'salary_num_mean'})
# Out:
#                   count_vacancy  salary_num_mean
# employer_name
# 12Go Asia                     1            0.000
# 2ГИС                          7            0.000
# A1 SolarStore                 2            0.000
# ALSECO, АО                    1            0.000
# AMarkets                      2            0.000
# ...                         ...              ...
# Эр-1                          2            0.000
# Юрент                         1       100000.000
# Яндекс                        8            0.000
# Яндекс Практикум              3            0.000
# билайн                        8            0.000
#
# [524 rows x 2 columns]

# %% [raw]
# Какие скиллы чаще всего требуются? Выведите топ-10 требуемых скиллов. (3)

# %%
from collections import Counter

key_skills_all = df['key_skills'].explode()
key_skills_all_count = Counter(key_skills_all)
top_10 = key_skills_all_count.most_common(10)
for i,j in top_10:
    print(i)
# Out:
# Python
# SQL
# ETL
# Big Data
# Hadoop
# PostgreSQL
# DWH
# Clickhouse
# Английский язык
# Математический анализ

# %% [raw]
# Постройте гистограмму распределения зарплаты среди вакансий в рублях. (2)

# %%
df[df['currency']=='RUR']['salary_num'].plot.hist()
# Отображение гистограммы
plt.show()

# %% [raw]
# Постройте boxplot зарплаты с группировкой по полю experience (2)

# %%
df[df['currency']=='RUR'].boxplot(column='salary_num', by='experience')
# Out:
# <Axes: title={'center': 'salary_num'}, xlabel='experience'>

# %% [raw]
# Попробуйте ответить на какой-нибудь вопрос по данным, не заданный ранее. Никак не ограничиваем вашу фантазию (3)

# %%
# Выведите среднюю зарплату в разных валютах, сгруппированных по городам
pd.set_option('display.float_format', lambda x: '%.3f' % x)
area_group = df.groupby(['area', 'currency'], as_index=False).agg(salary_mean = ('salary_num', 'mean'))
area_group[area_group['currency'] != 0]
# Out:
#                               area currency  salary_mean
# 3                           Алматы      KZT   740909.091
# 4                           Алматы      RUR    50000.000
# 8                           Астана      KZT   286666.667
# 16                          Брянск      RUR    70000.000
# 19                     Владивосток      RUR    68700.000
# 22                         Воронеж      RUR    25000.000
# 27                    Екатеринбург      RUR    77500.000
# 32                       Иннополис      RUR    70000.000
# 33                         Иркутск      RUR    50000.000
# 34                      Йошкар-Ола      RUR    40000.000
# 36                          Казань      RUR    82500.000
# 44                            Кипр      EUR     2375.000
# 45                            Кипр      USD      500.000
# 46       Киров (Кировская область)      RUR    10000.000
# 51                       Краснодар      RUR   240000.000
# 57                    Магнитогорск      RUR    31500.000
# 61                           Минск      BYR     6000.000
# 63                          Москва      EUR     2375.000
# 64                          Москва      RUR   155806.422
# 65                          Москва      USD     2257.143
# 69                 Нижний Новгород      RUR    71487.500
# 71                     Новосибирск      RUR   106666.667
# 73   Одинцово (Московская область)      RUR   120000.000
# 80                           Пермь      RUR   170000.000
# 85                  Ростов-на-Дону      RUR    22500.000
# 88                          Самара      RUR   100833.333
# 90                       Самарканд      UZS        0.000
# 92                 Санкт-Петербург      RUR   162727.273
# 93                 Санкт-Петербург      USD     1500.000
# 98                          Сербия      USD      950.000
# 100                           Сочи      RUR     5000.000
# 105                        Ташкент      USD     1500.000
# 106                        Ташкент      UZS  8000000.000
# 108                        Тбилиси      USD     1783.333
# 112                       Тольятти      RUR     7000.000
# 122                      Хабаровск      RUR    66100.000

# %% [raw]
# Список столбцов:
# item_id - id товара
# product_category_name - id категории
# month_year - первое число месяца, за который взяты данные
# qty - количество
# total_price - суммарная стоимость
# unit_price - цена
# product_name_lenght
# product_description_lenght
# holiday - количество праздников в месяце
# volume - объем
# comp_price - цена у одного из конкурентов
#
#
# Посмотрите на датасет, выведите первые пять строк и список столбцов (0.1)
# Сколько в датасете строк и столбцов? (0.4)
# Есть ли пропуски? (0.5)
# Есть ли в датасете полные дубли? Если да, удалите их. (1)
# Выведите описательные статистики по переменным. (1)
# Используя pd.to_datetime, приведите столбец month_year к дате. (1)
# Создайте столбцы year и month. (1)
# Какой период времени покрывается данными? (1)
# Сколько в датасете товаров? Сколько категорий? (1)
# Создайте столбец category_median_price, который будет содержать медианную цену категории (у строк с одним значением product_category_name) будет одно значение этого столбца. (2)
# Есть ли в датасете аномальные значения полей qty, unit_price, total_price? (2)
# В какой категории самая высокая средняя цена товара? (2)
# Постройте scatter plot зависимости спроса (qty) от цены (unit price) (1). Напишите функцию, которая принимает на вход датасет, названия столбцов, название графика и осей и рисует scatter plot. Нариcуйте все scatter plot от числовых переменных. (1)
# Сделайте поле lag_price - цена в предыдущем месяце. Если ее нет, оставьте поле пустым. (2)
# Создайте поле is_price_up, которое принимает значение 1, если цена выросла по сравнению с предыдущим месяцем. (2)
# Постройте тепловую карту корреляций переменных. Сделайте выводы. (2)
# Постройте таблицу, где по столбцам название товаров, а по строкам - дата (месяц-год). В ячейках должно быть количество проданного товара. (3)
# Продажи каких товаров коррелируют между собой? (3)
# Попробуйте ответить на какой-нибудь вопрос по данным, не заданный ранее. Никак не ограничиваем вашу фантазию (3)

# %% [raw]
# Посмотрите на датасет, выведите первые пять строк и список столбцов (0.1)

# %%
df = pd.read_csv('items.csv').drop('Unnamed: 0', axis=1)

# %%
df.head()
# Out:
#   item_id product_category_name  month_year  qty  total_price  unit_price  \
# 0    bed1        bed_bath_table  01-05-2017    1       45.950      45.950
# 1    bed1        bed_bath_table  01-06-2017    3      137.850      45.950
# 2    bed1        bed_bath_table  01-07-2017    6      275.700      45.950
# 3    bed1        bed_bath_table  01-08-2017    4      183.800      45.950
# 4    bed1        bed_bath_table  01-09-2017    2       91.900      45.950
#
#    product_name_lenght  product_description_lenght  customers  holiday  \
# 0                   39                         161         57        1
# 1                   39                         161         61        1
# 2                   39                         161        123        1
# 3                   39                         161         90        1
# 4                   39                         161         54        1
#
#    volume  comp_price
# 0    3800      45.950
# 1    3800      45.950
# 2    3800      45.950
# 3    3800      45.950
# 4    3800      45.950

# %%
df.columns
# Out:
# Index(['item_id', 'product_category_name', 'month_year', 'qty', 'total_price',
#        'unit_price', 'product_name_lenght', 'product_description_lenght',
#        'customers', 'holiday', 'volume', 'comp_price'],
#       dtype='object')

# %% [raw]
# Сколько в датасете строк и столбцов? (0.4)

# %%
df.shape
# Out:
# (676, 12)

# %% [raw]
# Есть ли пропуски? (0.5)

# %%
print(df.isnull().any(), '\n')
print(df.isnull().any().any())
# Out:
# item_id                       False
# product_category_name         False
# month_year                    False
# qty                           False
# total_price                   False
# unit_price                    False
# product_name_lenght           False
# product_description_lenght    False
# customers                     False
# holiday                       False
# volume                        False
# comp_price                    False
# dtype: bool
#
# False

# %% [raw]
# Есть ли в датасете полные дубли? Если да, удалите их. (1)

# %%
duplicates = df.duplicated()
num_duplicates = duplicates.sum()
print(num_duplicates)#0 полных дубликатов
#df.drop_duplicates()
# Out:
# 0

# %% [raw]
# Выведите описательные статистики по переменным. (1)

# %%
df.describe()
# Out:
#           qty  total_price  unit_price  product_name_lenght  \
# count 676.000      676.000     676.000              676.000
# mean   14.496     1422.709     106.497               48.720
# std    15.443     1700.123      76.183                9.421
# min     1.000       19.900      19.900               29.000
# 25%     4.000      333.700      53.900               40.000
# 50%    10.000      807.890      89.900               51.000
# 75%    18.000     1887.322     129.990               57.000
# max   122.000    12095.000     364.000               60.000
#
#        product_description_lenght  customers  holiday    volume  comp_price
# count                     676.000    676.000  676.000   676.000     676.000
# mean                      767.399     81.028    1.494 10664.627      84.183
# std                       655.205     62.056    0.940  9172.802      47.746
# min                       100.000      1.000    0.000   640.000      19.900
# 25%                       339.000     34.000    1.000  3510.000      53.786
# 50%                       501.000     62.000    1.000  8000.000      59.900
# 75%                       903.000    116.000    2.000 15750.000      99.990
# max                      3006.000    339.000    4.000 32736.000     255.610

# %%
df.describe(include = 'object')
# Out:
#         item_id product_category_name  month_year
# count       676                   676         676
# unique       52                     9          20
# top     health7          garden_tools  01-03-2018
# freq         20                   160          50

# %% [raw]
# Используя pd.to_datetime, приведите столбец month_year к дате. (1)

# %%
df['month_year'] = df['month_year'].apply(lambda x: pd.to_datetime(x)).dt.to_period("D")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 676 entries, 0 to 675
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   item_id                     676 non-null    object
#  1   product_category_name       676 non-null    object
#  2   month_year                  676 non-null    period[D]
#  3   qty                         676 non-null    int64
#  4   total_price                 676 non-null    float64
#  5   unit_price                  676 non-null    float64
#  6   product_name_lenght         676 non-null    int64
#  7   product_description_lenght  676 non-null    int64
#  8   customers                   676 non-null    int64
#  9   holiday                     676 non-null    int64
#  10  volume                      676 non-null    int64
#  11  comp_price                  676 non-null    float64
#  12  year                        676 non-null    int32
#  13  month                       676 non-null    int32
# dtypes: float64(3), int32(2), int64(6), object(2), period[D](1)
# memory usage: 68.8+ KB

# %% [raw]
# Создайте столбцы year и month. (1)

# %%
df['year'] = df['month_year'].dt.year
df['month'] = df['month_year'].dt.month
df.tail()
# Out:
#     item_id product_category_name  month_year  qty  total_price  unit_price  \
# 671    bed5        bed_bath_table  2017-01-05    1      215.000     215.000
# 672    bed5        bed_bath_table  2017-01-06   10     2090.000     209.000
# 673    bed5        bed_bath_table  2017-01-07   59    12095.000     205.000
# 674    bed5        bed_bath_table  2017-01-08   52    10375.000     199.510
# 675    bed5        bed_bath_table  2017-01-09   32     5222.360     163.399
#
#      product_name_lenght  product_description_lenght  customers  holiday  \
# 671                   56                         162         57        1
# 672                   56                         162         61        1
# 673                   56                         162        123        1
# 674                   56                         162         90        1
# 675                   56                         162         54        1
#
#      volume  comp_price  year  month
# 671   12600      45.950  2017      1
# 672   12600      45.950  2017      1
# 673   12600      45.950  2017      1
# 674   12600      45.950  2017      1
# 675   12600      45.950  2017      1

# %% [raw]
# Какой период времени покрывается данными? (1)

# %%
print(f'Период времени: {df['month_year'].min()} - {df['month_year'].max()}')
# Out:
# Период времени: 2017-01-01 - 2018-01-08

# %% [raw]
# Сколько в датасете товаров? Сколько категорий? (1)

# %% [raw]
# Создайте столбец category_median_price, который будет содержать медианную цену категории (у строк с одним значением product_category_name) будет одно значение этого столбца. (2)

# %% [raw]
# Есть ли в датасете аномальные значения полей qty, unit_price, total_price? (2)

# %% [raw]
# В какой категории самая высокая средняя цена товара? (2)

# %% [raw]
# Постройте scatter plot зависимости спроса (qty) от цены (unit price) (1).

# %% [raw]
# Напишите функцию, которая принимает на вход датасет, названия столбцов, название графика и осей и рисует scatter plot. Нариcуйте все scatter plot от числовых переменных. (1)

# %% [raw]
# Сделайте поле lag_price - цена в предыдущем месяце. Если ее нет, оставьте поле пустым. (2)

# %% [raw]
# Создайте поле is_price_up, которое принимает значение 1, если цена выросла по сравнению с предыдущим месяцем. (2)

# %% [raw]
# Постройте тепловую карту корреляций переменных. Сделайте выводы. (2)

# %% [raw]
# Постройте таблицу, где по столбцам название товаров, а по строкам - дата (месяц-год). В ячейках должно быть количество проданного товара. (3)

# %% [raw]
# Продажи каких товаров коррелируют между собой? (3)

# %% [raw]
# Попробуйте ответить на какой-нибудь вопрос по данным, не заданный ранее. Никак не ограничиваем вашу фантазию (3)
