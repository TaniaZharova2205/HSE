# %% [markdown]
# <a href="https://colab.research.google.com/github/Murcha1990/ML_AI24/blob/main/Lesson22_RecSys/ML_AI_recsys3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Рекомендательные системы

# %% [markdown]
# В этом задании будем практиковаться в реализации рекомендательных систем.
#
# Воспользуемся небольшим датасетом с Kaggle: [Articles Sharing and Reading from CI&T Deskdrop](https://www.kaggle.com/gspmoreira/articles-sharing-reading-from-cit-deskdrop).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np
import math

from sklearn.model_selection import train_test_split

from tqdm import tqdm_notebook

# %% [markdown]
# ## Часть 1. Загрузка данных

# %% [markdown]
# Загрузим Deskdrop dataset, включающийся в себе информацию за один год платформы, где пользователи читают статьи.

# %%
interactions_df = pd.read_csv('https://raw.githubusercontent.com/aiedu-courses/stepik_applied_tasks/main/datasets/users_interactions.csv')
interactions_df.head()
# Out:
#     timestamp eventType            contentId             personId  \
# 0  1465413032      VIEW -3499919498720038879 -8845298781299428018
# 1  1465412560      VIEW  8890720798209849691 -1032019229384696495
# 2  1465416190      VIEW   310515487419366995 -1130272294246983140
# 3  1465413895    FOLLOW   310515487419366995   344280948527967603
# 4  1465412290      VIEW -7820640624231356730  -445337111692715325
#
#              sessionId                                          userAgent  \
# 0  1264196770339959068                                                NaN
# 1  3621737643587579081  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2...
# 2  2631864456530402479                                                NaN
# 3 -3167637573980064150                                                NaN
# 4  5611481178424124714                                                NaN
#
#   userRegion userCountry
# 0        NaN         NaN
# 1         NY          US
# 2        NaN         NaN
# 3        NaN         NaN
# 4        NaN         NaN

# %% [markdown]
# В колонке eventType описаны действия, которые могли совершать пользователи над статьёй:
# - VIEW
# - LIKE
# - COMMENT CREATED
# - FOLLOW
# - BOOKMARK

# %%
interactions_df.personId = interactions_df.personId.astype(str)
interactions_df.contentId = interactions_df.contentId.astype(str)

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# В логах встречаются различные действия пользователей. Однако мы хотим работать лишь с одной величиной, характеризующей всё взаимодействие пользователя со статьёй. Предлагается задать действиям следующие веса:

# %%
event_type_strength = {
   'VIEW': 1.0,
   'LIKE': 2.0,
   'BOOKMARK': 2.5,
   'FOLLOW': 3.0,
   'COMMENT CREATED': 4.0,
}

# %% [markdown]
# Посчитаем числовую величину "оценки" пользователем статьи с указанными выше весами.

# %%
interactions_df['eventStrength'] = interactions_df.eventType.apply(lambda x: event_type_strength[x])
interactions_df['eventStrength']
# Out:
# 0        1.0
# 1        1.0
# 2        1.0
# 3        3.0
# 4        1.0
#         ...
# 72307    2.0
# 72308    1.0
# 72309    1.0
# 72310    1.0
# 72311    1.0
# Name: eventStrength, Length: 72312, dtype: float64

# %% [markdown]
# Ремендательные системы подвержены проблеме холодного старта. Будем работать только с теми пользователями, которые взаимодействовали хотя бы с 5-ю материалами.
#
# Оставим только таких пользователей.

# %%
users_interactions_count_df = (
    interactions_df
    .groupby(['personId', 'contentId'])
    .first()
    .reset_index()
    .groupby('personId').size())
print('number of users:', len(users_interactions_count_df))

users_with_enough_interactions_df = \
    users_interactions_count_df[users_interactions_count_df >= 5].reset_index()[['personId']]
print('number of users with at least 5 interactions:',len(users_with_enough_interactions_df))
# Out:
# number of users: 1895
# number of users with at least 5 interactions: 1140

# %%
users_interactions_count_df.hist(bins=30)
# Out:
# <Axes: >

# %% [markdown]
# Оставим только те взаимодействия, которые касаются только отфильтрованных пользователей.

# %%
interactions_from_selected_users_df = interactions_df.loc[np.in1d(interactions_df.personId,
            users_with_enough_interactions_df)]

# %%
print('number of interactions before:', interactions_df.shape)
print('number of interactions after:', interactions_from_selected_users_df.shape)
# Out:
# number of interactions before: (72312, 9)
# number of interactions after: (69868, 9)

# %% [markdown]
# В данной постановке каждый пользователей мог взаимодействовать с каждой статьей более одного раза (как минимум совершая различные действия). Предлагается "схлопнуть" все действия в одно взаимодействие с весом, равным сумме весов.
#
# Однако полученное число будет в том числе тем больше, чем больше действий произвел человек. Чтобы уменьшить разброс предлагается взять логарифм от полученного числа (можно придумывать другие веса действиям и по-другому обрабатывать значения).
#
# Также сохраним последнее значение времени взаимодействия для разделениея выборки на обучение и контроль.

# %%
def smooth_user_preference(x):
    return math.log(1+x, 2)

interactions_full_df = (
    interactions_from_selected_users_df
    .groupby(['personId', 'contentId']).eventStrength.sum()
    .apply(smooth_user_preference)
    .reset_index().set_index(['personId', 'contentId'])
)
interactions_full_df['last_timestamp'] = (
    interactions_from_selected_users_df
    .groupby(['personId', 'contentId'])['timestamp'].last()
)

interactions_full_df = interactions_full_df.reset_index()
interactions_full_df.head()
# Out:
#                personId             contentId  eventStrength  last_timestamp
# 0  -1007001694607905623  -5065077552540450930       1.000000      1470395911
# 1  -1007001694607905623  -6623581327558800021       1.000000      1487240080
# 2  -1007001694607905623   -793729620925729327       1.000000      1472834892
# 3  -1007001694607905623   1469580151036142903       1.000000      1487240062
# 4  -1007001694607905623   7270966256391553686       1.584963      1485994324

# %% [markdown]
# Разобьём выборку на обучение и контроль по времени.

# %%
split_ts = 1475519530
interactions_train_df = interactions_full_df.loc[interactions_full_df.last_timestamp < split_ts].copy()
interactions_test_df = interactions_full_df.loc[interactions_full_df.last_timestamp >= split_ts].copy()

print('number of interactions on Train set: %d' % len(interactions_train_df))
print('number of interactions on Test set: %d' % len(interactions_test_df))

interactions_train_df
# Out:
# number of interactions on Train set: 29329
# number of interactions on Test set: 9777
#                    personId             contentId  eventStrength  \
# 0      -1007001694607905623  -5065077552540450930            1.0
# 2      -1007001694607905623   -793729620925729327            1.0
# 6      -1032019229384696495  -1006791494035379303            1.0
# 7      -1032019229384696495  -1039912738963181810            1.0
# 8      -1032019229384696495  -1081723567492738167            2.0
# ...                     ...                   ...            ...
# 39099    997469202936578234   9112765177685685246            2.0
# 39100    998688566268269815  -1255189867397298842            1.0
# 39101    998688566268269815   -401664538366009049            1.0
# 39103    998688566268269815   6881796783400625893            1.0
# 39105    998688566268269815    739747367187387064            1.0
#
#        last_timestamp
# 0          1470395911
# 2          1472834892
# 6          1469129122
# 7          1459376415
# 8          1464054093
# ...               ...
# 39099      1472479493
# 39100      1474567164
# 39101      1474567449
# 39103      1474567675
# 39105      1474567514
#
# [29329 rows x 4 columns]

# %% [markdown]
# Для удобства подсчёта качества запишем данные в формате, где строка соответствует пользователю, а столбцы будут истинными метками и предсказаниями в виде списков.

# %%
interactions = (
    interactions_train_df
    .groupby('personId')['contentId'].agg(lambda x: list(x))
    .reset_index()
    .rename(columns={'contentId': 'true_train'})
    .set_index('personId')
)

interactions['true_test'] = (
    interactions_test_df
    .groupby('personId')['contentId'].agg(lambda x: list(x))
)

interactions.loc[pd.isnull(interactions.true_test), 'true_test'] = [
    [''] for x in range(len(interactions.loc[pd.isnull(interactions.true_test), 'true_test']))]

interactions.head(5)
# Out:
#                                                              true_train  \
# personId
# -1007001694607905623        [-5065077552540450930, -793729620925729327]
# -1032019229384696495  [-1006791494035379303, -1039912738963181810, -...
# -108842214936804958   [-1196068832249300490, -133139342397538859, -1...
# -1130272294246983140  [-1150591229250318592, -1196068832249300490, -...
# -1160159014793528221  [-133139342397538859, -387651900461462767, 377...
#
#                                                               true_test
# personId
# -1007001694607905623  [-6623581327558800021, 1469580151036142903, 72...
# -1032019229384696495  [-1415040208471067980, -2555801390963402198, -...
# -108842214936804958   [-2780168264183400543, -3060116862184714437, -...
# -1130272294246983140  [-1606980109000976010, -1663441888197894674, -...
# -1160159014793528221                             [-3462051751080362224]

# %% [markdown]
# ## Метрика качества

# %% [markdown]
# Качество модели будем оценивать при помощи метрики precision@10 для каждого пользователя (доля угаданных рекомендаций). Усредним ее по всем пользователям.

# %%
def calc_precision(column):
    return (
        interactions
        .apply(
            lambda row:
            len(set(row['true_test']).intersection(
                set(row[column]))) /
            min(len(row['true_test']) + 0.001, 10.0),
            axis=1)).mean()

# %% [markdown]
# Составим матрицу "оценок" пользователей. Нули будут обозначать отсутствие взаимодействия.

# %%
ratings = pd.pivot_table(
    interactions_train_df,
    values='eventStrength',
    index='personId',
    columns='contentId').fillna(0)

# %% [markdown]
# ## Часть 2. Контентные  модели

# %% [markdown]
# В этой части реализуем альтернативный подход к рекомендательным системам — контентные модели.

# %% [markdown]
# Теперь мы будем оперировать не матрицей с оценками, а классической для машинного обучения матрицей объекты-признаки. Каждый объект будет характеризовать пару user-item и содержать признаки, описывающие как пользователя, так и товар. Кроме этого признаки могут описывать и саму пару целиком.
#
# Матрица со всеми взаимодействиями уже получена нами на этапа разбиения выборки на две части.

# %% [markdown]
# * Будем обучать классификатор на взаимодействие, а для него нужны отрицательные примеры. Добавим случайные отсутствующие взаимодействия как отрицательные
#
# * Заметим, что модель оценивает каждую пару потенциального взаимодействия, а значит, надо подготовить выборку из всех возможных пар из пользователей и статей

# %%
test_personId = np.repeat(interactions.index, len(ratings.columns))
test_contentId = list(ratings.columns) * len(interactions)
test = pd.DataFrame(
    np.array([test_personId, test_contentId]).T,
    columns=['personId', 'contentId'])

interactions_train_df = pd.concat((
    interactions_train_df,
    test.loc[
        np.random.permutation(test.index)[
            :4*len(interactions_train_df)]]), ignore_index=True)
interactions_train_df.eventStrength.fillna(0, inplace=True)
# Out:
# <ipython-input-15-0743bb745623>:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   interactions_train_df.eventStrength.fillna(0, inplace=True)

# %% [markdown]
# Загрузим метаинформацию о статьях.
#
# Сразу оставим только информацию о статьях, отображающихся на сайте (`CONTENT SHARED`), так как бесполезно рекомендовать удаленные статьи.

# %%
articles_df = pd.read_csv("https://raw.githubusercontent.com/aiedu-courses/stepik_applied_tasks/main/datasets/shared_articles.csv")

articles_df = articles_df[articles_df['eventType'] == 'CONTENT SHARED']
articles_df.head(2)

articles_df.contentId = articles_df.contentId.astype(str)

# %%
articles_df.head(2)
# Out:
#     timestamp       eventType             contentId       authorPersonId  \
# 1  1459193988  CONTENT SHARED  -4110354420726924665  4340306774493623681
# 2  1459194146  CONTENT SHARED  -7292285110016212249  4340306774493623681
#
#        authorSessionId authorUserAgent authorRegion authorCountry contentType  \
# 1  8940341205206233829             NaN          NaN           NaN        HTML
# 2  8940341205206233829             NaN          NaN           NaN        HTML
#
#                                                  url  \
# 1  http://www.nytimes.com/2016/03/28/business/dea...
# 2  http://cointelegraph.com/news/bitcoin-future-w...
#
#                                                title  \
# 1  Ethereum, a Virtual Currency, Enables Transact...
# 2  Bitcoin Future: When GBPcoin of Branson Wins O...
#
#                                                 text lang
# 1  All of this work is still very early. The firs...   en
# 2  The alarm clock wakes me at 8:00 with stream o...   en

# %% [markdown]
# Придумаем и добавим признаков о пользователях и статьях. Сначала добавим информацию о статьях в данные о взаимодействиях.

# %%
interactions_train_df = interactions_train_df.merge(articles_df, how='left', on='contentId')
interactions_test_df = interactions_test_df.merge(articles_df, how='left', on='contentId')

# %%
features_start = len(interactions_train_df.columns)

# %% [markdown]
# После обучения модели нам придётся делать предсказания на тестовой выборке для всех возможных пар статья-пользователь. Подготовим такую матрицу, чтобы параллельно посчитать признаки для неё.

# %%
test_personId = np.repeat(interactions.index, len(articles_df))
test_contentId = list(articles_df.contentId) * len(interactions)
test = pd.DataFrame(
    np.array([test_personId, test_contentId]).T,
    columns=['personId', 'contentId'])
test = test.merge(articles_df, how='left', on='contentId')

test.head()
# Out:
#                personId             contentId   timestamp       eventType  \
# 0  -1007001694607905623  -4110354420726924665  1459193988  CONTENT SHARED
# 1  -1007001694607905623  -7292285110016212249  1459194146  CONTENT SHARED
# 2  -1007001694607905623  -6151852268067518688  1459194474  CONTENT SHARED
# 3  -1007001694607905623   2448026894306402386  1459194497  CONTENT SHARED
# 4  -1007001694607905623  -2826566343807132236  1459194522  CONTENT SHARED
#
#         authorPersonId      authorSessionId authorUserAgent authorRegion  \
# 0  4340306774493623681  8940341205206233829             NaN          NaN
# 1  4340306774493623681  8940341205206233829             NaN          NaN
# 2  3891637997717104548 -1457532940883382585             NaN          NaN
# 3  4340306774493623681  8940341205206233829             NaN          NaN
# 4  4340306774493623681  8940341205206233829             NaN          NaN
#
#   authorCountry contentType  \
# 0           NaN        HTML
# 1           NaN        HTML
# 2           NaN        HTML
# 3           NaN        HTML
# 4           NaN        HTML
#
#                                                  url  \
# 0  http://www.nytimes.com/2016/03/28/business/dea...
# 1  http://cointelegraph.com/news/bitcoin-future-w...
# 2  https://cloudplatform.googleblog.com/2016/03/G...
# 3  https://bitcoinmagazine.com/articles/ibm-wants...
# 4  http://www.coindesk.com/ieee-blockchain-oxford...
#
#                                                title  \
# 0  Ethereum, a Virtual Currency, Enables Transact...
# 1  Bitcoin Future: When GBPcoin of Branson Wins O...
# 2                       Google Data Center 360° Tour
# 3  IBM Wants to "Evolve the Internet" With Blockc...
# 4  IEEE to Talk Blockchain at Cloud Computing Oxf...
#
#                                                 text lang
# 0  All of this work is still very early. The firs...   en
# 1  The alarm clock wakes me at 8:00 with stream o...   en
# 2  We're excited to share the Google Data Center ...   en
# 3  The Aite Group projects the blockchain market ...   en
# 4  One of the largest and oldest organizations fo...   en

# %% [markdown]
# Добавим признаки-индикаторы возможных значений contentType.

# %%
interactions_train_df['is_HTML'] = interactions_train_df.contentType == 'HTML'
interactions_train_df['is_RICH'] = interactions_train_df.contentType == 'RICH'
interactions_train_df['is_VIDEO'] = interactions_train_df.contentType == 'VIDEO'

test['is_HTML'] = test.contentType == 'HTML'
test['is_RICH'] = test.contentType == 'RICH'
test['is_VIDEO'] = test.contentType == 'VIDEO'

# %% [markdown]
# Добавим признаки "длина названия" и "длина текста" + некоторые проверки на ключевые слова.

# %%
interactions_train_df['title_length'] = interactions_train_df.title.fillna('').apply(len)
interactions_train_df['text_length'] = interactions_train_df.text.fillna('').apply(len)

test['title_length'] = test.title.fillna('').apply(len)
test['text_length'] = test.text.fillna('').apply(len)

interactions_train_df['has_new'] = \
    interactions_train_df.title.fillna('').apply(lambda x: 'new' in x.lower())
interactions_train_df['has_why'] = \
    interactions_train_df.title.fillna('').apply(lambda x: 'why' in x.lower())
interactions_train_df['has_how'] = \
    interactions_train_df.title.fillna('').apply(lambda x: 'how' in x.lower())
interactions_train_df['has_ai'] = \
    interactions_train_df.title.fillna('').apply(lambda x: 'ai' in x.lower())

test['has_new'] = \
    test.title.fillna('').apply(lambda x: 'new' in x.lower())
test['has_why'] = \
    test.title.fillna('').apply(lambda x: 'why' in x.lower())
test['has_how'] = \
    test.title.fillna('').apply(lambda x: 'how' in x.lower())
test['has_ai'] = \
    test.title.fillna('').apply(lambda x: 'ai' in x.lower())

# %% [markdown]
# Добавим признаки-индикаторы языка.

# %%
interactions_train_df['is_lang_en'] = interactions_train_df.lang == 'en'
interactions_train_df['is_lang_pt'] = interactions_train_df.lang == 'pt'

test['is_lang_en'] = test.lang == 'en'
test['is_lang_pt'] = test.lang == 'pt'

# %% [markdown]
# Обучим на полученных признаках градиентный бустинг.

# %%
# !pip install catboost -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 8.7 MB/s eta 0:00:00

# %% [markdown]
# Будем использовать в модели только сгенерированные признаки.

# %%
interactions_train_df[interactions_train_df.columns[features_start:]]
# Out:
#         is_HTML  is_RICH  is_VIDEO  title_length  text_length  has_new  \
# 0          True    False     False            63          655    False
# 1          True    False     False            30         2495    False
# 2          True    False     False            89         1221    False
# 3          True    False     False           102          801    False
# 4          True    False     False            74         1860     True
# ...         ...      ...       ...           ...          ...      ...
# 146640     True    False     False            49         9603    False
# 146641     True    False     False            64         5627    False
# 146642     True    False     False            47         1313    False
# 146643     True    False     False            56         1611    False
# 146644     True    False     False           119         3653    False
#
#         has_why  has_how  has_ai  is_lang_en  is_lang_pt
# 0         False    False    True       False        True
# 1         False    False   False        True       False
# 2         False    False   False        True       False
# 3         False    False   False        True       False
# 4         False    False   False        True       False
# ...         ...      ...     ...         ...         ...
# 146640    False    False   False        True       False
# 146641    False    False   False        True       False
# 146642    False    False    True       False        True
# 146643    False    False   False        True       False
# 146644    False    False    True       False        True
#
# [146645 rows x 11 columns]

# %% [markdown]
# Обучаем классификатор на прогноз взаимодействия пользователя и статьи.

# %%
import catboost

model = catboost.CatBoostClassifier()
model.fit(interactions_train_df[interactions_train_df.columns[features_start:]],
          np.array(interactions_train_df.eventStrength > 0, dtype=int))
# Out:
# Learning rate set to 0.086682
# 0:	learn: 0.6577954	total: 79.6ms	remaining: 1m 19s
# 1:	learn: 0.6290962	total: 101ms	remaining: 50.2s
# 2:	learn: 0.6051518	total: 133ms	remaining: 44.1s
# 3:	learn: 0.5859233	total: 154ms	remaining: 38.3s
# 4:	learn: 0.5698955	total: 192ms	remaining: 38.3s
# 5:	learn: 0.5569175	total: 219ms	remaining: 36.2s
# 6:	learn: 0.5459737	total: 244ms	remaining: 34.6s
# 7:	learn: 0.5371394	total: 269ms	remaining: 33.4s
# 8:	learn: 0.5300217	total: 288ms	remaining: 31.7s
# 9:	learn: 0.5242120	total: 313ms	remaining: 31s
# 10:	learn: 0.5192437	total: 337ms	remaining: 30.3s
# 11:	learn: 0.5149077	total: 365ms	remaining: 30.1s
# 12:	learn: 0.5112380	total: 398ms	remaining: 30.2s
# 13:	learn: 0.5083109	total: 423ms	remaining: 29.8s
# 14:	learn: 0.5060057	total: 443ms	remaining: 29.1s
# 15:	learn: 0.5041039	total: 466ms	remaining: 28.7s
# 16:	learn: 0.5022416	total: 491ms	remaining: 28.4s
# 17:	learn: 0.5009244	total: 512ms	remaining: 28s
# 18:	learn: 0.4997076	total: 539ms	remaining: 27.8s
# 19:	learn: 0.4987975	total: 560ms	remaining: 27.4s
# 20:	learn: 0.4977791	total: 587ms	remaining: 27.4s
# 21:	learn: 0.4968091	total: 618ms	remaining: 27.5s
# 22:	learn: 0.4962171	total: 644ms	remaining: 27.4s
# 23:	learn: 0.4955342	total: 674ms	remaining: 27.4s
# 24:	learn: 0.4948845	total: 702ms	remaining: 27.4s
# 25:	learn: 0.4945433	total: 727ms	remaining: 27.2s
# 26:	learn: 0.4940187	total: 753ms	remaining: 27.1s
# 27:	learn: 0.4936691	total: 778ms	remaining: 27s
# 28:	learn: 0.4932357	total: 807ms	remaining: 27s
# 29:	learn: 0.4929155	total: 846ms	remaining: 27.4s
# 30:	learn: 0.4925961	total: 885ms	remaining: 27.7s
# 31:	learn: 0.4922009	total: 915ms	remaining: 27.7s
# 32:	learn: 0.4918755	total: 944ms	remaining: 27.7s
# 33:	learn: 0.4917813	total: 964ms	remaining: 27.4s
# 34:	learn: 0.4914492	total: 990ms	remaining: 27.3s
# 35:	learn: 0.4912340	total: 1.02s	remaining: 27.2s
# 36:	learn: 0.4910169	total: 1.05s	remaining: 27.3s
# 37:	learn: 0.4907192	total: 1.08s	remaining: 27.2s
# 38:	learn: 0.4903833	total: 1.1s	remaining: 27.1s
# 39:	learn: 0.4902085	total: 1.13s	remaining: 27s
# 40:	learn: 0.4900739	total: 1.15s	remaining: 27s
# 41:	learn: 0.4898950	total: 1.19s	remaining: 27s
# 42:	learn: 0.4896180	total: 1.21s	remaining: 27s
# 43:	learn: 0.4895051	total: 1.24s	remaining: 27s
# 44:	learn: 0.4893659	total: 1.27s	remaining: 27s
# 45:	learn: 0.4891738	total: 1.3s	remaining: 26.9s
# 46:	learn: 0.4889482	total: 1.32s	remaining: 26.9s
# 47:	learn: 0.4886475	total: 1.35s	remaining: 26.9s
# 48:	learn: 0.4884632	total: 1.39s	remaining: 27s
# 49:	learn: 0.4883336	total: 1.46s	remaining: 27.7s
# 50:	learn: 0.4881529	total: 1.51s	remaining: 28s
# 51:	learn: 0.4880637	total: 1.56s	remaining: 28.5s
# 52:	learn: 0.4878585	total: 1.63s	remaining: 29.1s
# 53:	learn: 0.4876888	total: 1.69s	remaining: 29.6s
# 54:	learn: 0.4874427	total: 1.75s	remaining: 30s
# 55:	learn: 0.4873101	total: 1.78s	remaining: 30s
# 56:	learn: 0.4871418	total: 1.84s	remaining: 30.4s
# 57:	learn: 0.4869267	total: 1.88s	remaining: 30.5s
# 58:	learn: 0.4867732	total: 1.95s	remaining: 31s
# 59:	learn: 0.4866032	total: 1.98s	remaining: 31s
# 60:	learn: 0.4864077	total: 2.02s	remaining: 31s
# 61:	learn: 0.4862772	total: 2.06s	remaining: 31.1s
# 62:	learn: 0.4860934	total: 2.1s	remaining: 31.2s
# 63:	learn: 0.4860064	total: 2.13s	remaining: 31.1s
# 64:	learn: 0.4859129	total: 2.16s	remaining: 31.1s
# 65:	learn: 0.4857865	total: 2.19s	remaining: 30.9s
# 66:	learn: 0.4856579	total: 2.21s	remaining: 30.8s
# 67:	learn: 0.4855132	total: 2.24s	remaining: 30.7s
# 68:	learn: 0.4854127	total: 2.27s	remaining: 30.6s
# 69:	learn: 0.4853273	total: 2.3s	remaining: 30.5s
# 70:	learn: 0.4851720	total: 2.32s	remaining: 30.4s
# 71:	learn: 0.4851192	total: 2.35s	remaining: 30.3s
# 72:	learn: 0.4849992	total: 2.39s	remaining: 30.3s
# 73:	learn: 0.4849047	total: 2.41s	remaining: 30.2s
# 74:	learn: 0.4847902	total: 2.44s	remaining: 30.1s
# 75:	learn: 0.4846861	total: 2.47s	remaining: 30s
# 76:	learn: 0.4845817	total: 2.5s	remaining: 30s
# 77:	learn: 0.4843760	total: 2.52s	remaining: 29.9s
# 78:	learn: 0.4841885	total: 2.55s	remaining: 29.8s
# 79:	learn: 0.4840469	total: 2.58s	remaining: 29.7s
# 80:	learn: 0.4839337	total: 2.65s	remaining: 30s
# 81:	learn: 0.4837903	total: 2.71s	remaining: 30.3s
# 82:	learn: 0.4836839	total: 2.78s	remaining: 30.7s
# 83:	learn: 0.4835601	total: 2.86s	remaining: 31.1s
# 84:	learn: 0.4834253	total: 2.92s	remaining: 31.4s
# 85:	learn: 0.4833224	total: 2.98s	remaining: 31.7s
# 86:	learn: 0.4831834	total: 3.05s	remaining: 32s
# 87:	learn: 0.4830679	total: 3.13s	remaining: 32.5s
# 88:	learn: 0.4829124	total: 3.21s	remaining: 32.8s
# 89:	learn: 0.4828132	total: 3.28s	remaining: 33.2s
# 90:	learn: 0.4826998	total: 3.37s	remaining: 33.6s
# 91:	learn: 0.4825652	total: 3.45s	remaining: 34.1s
# 92:	learn: 0.4825204	total: 3.54s	remaining: 34.5s
# 93:	learn: 0.4823964	total: 3.62s	remaining: 34.9s
# 94:	learn: 0.4822792	total: 3.69s	remaining: 35.1s
# 95:	learn: 0.4821633	total: 3.79s	remaining: 35.7s
# 96:	learn: 0.4820252	total: 3.88s	remaining: 36.2s
# 97:	learn: 0.4819342	total: 3.96s	remaining: 36.4s
# 98:	learn: 0.4818544	total: 4.01s	remaining: 36.5s
# 99:	learn: 0.4817960	total: 4.05s	remaining: 36.4s
# 100:	learn: 0.4816005	total: 4.13s	remaining: 36.7s
# 101:	learn: 0.4815071	total: 4.22s	remaining: 37.2s
# 102:	learn: 0.4813760	total: 4.32s	remaining: 37.6s
# 103:	learn: 0.4812468	total: 4.43s	remaining: 38.1s
# 104:	learn: 0.4811902	total: 4.48s	remaining: 38.2s
# 105:	learn: 0.4811138	total: 4.54s	remaining: 38.3s
# 106:	learn: 0.4810056	total: 4.61s	remaining: 38.4s
# 107:	learn: 0.4809348	total: 4.69s	remaining: 38.7s
# 108:	learn: 0.4808501	total: 4.74s	remaining: 38.7s
# 109:	learn: 0.4807942	total: 4.83s	remaining: 39.1s
# 110:	learn: 0.4806965	total: 4.91s	remaining: 39.3s
# 111:	learn: 0.4806305	total: 4.97s	remaining: 39.4s
# 112:	learn: 0.4805290	total: 5.06s	remaining: 39.7s
# 113:	learn: 0.4804546	total: 5.13s	remaining: 39.9s
# 114:	learn: 0.4803408	total: 5.18s	remaining: 39.9s
# 115:	learn: 0.4802941	total: 5.26s	remaining: 40.1s
# 116:	learn: 0.4801811	total: 5.34s	remaining: 40.3s
# 117:	learn: 0.4801075	total: 5.41s	remaining: 40.5s
# 118:	learn: 0.4800293	total: 5.52s	remaining: 40.9s
# 119:	learn: 0.4799364	total: 5.62s	remaining: 41.2s
# 120:	learn: 0.4798723	total: 5.7s	remaining: 41.4s
# 121:	learn: 0.4797887	total: 5.77s	remaining: 41.5s
# 122:	learn: 0.4797305	total: 5.83s	remaining: 41.6s
# 123:	learn: 0.4796479	total: 5.91s	remaining: 41.8s
# 124:	learn: 0.4795502	total: 5.97s	remaining: 41.8s
# 125:	learn: 0.4794708	total: 6.04s	remaining: 41.9s
# 126:	learn: 0.4793724	total: 6.11s	remaining: 42s
# 127:	learn: 0.4792347	total: 6.17s	remaining: 42.1s
# 128:	learn: 0.4791794	total: 6.25s	remaining: 42.2s
# 129:	learn: 0.4790814	total: 6.33s	remaining: 42.4s
# 130:	learn: 0.4790021	total: 6.41s	remaining: 42.5s
# 131:	learn: 0.4789076	total: 6.48s	remaining: 42.6s
# 132:	learn: 0.4788490	total: 6.55s	remaining: 42.7s
# 133:	learn: 0.4787811	total: 6.62s	remaining: 42.8s
# 134:	learn: 0.4786638	total: 6.7s	remaining: 42.9s
# 135:	learn: 0.4785890	total: 6.79s	remaining: 43.2s
# 136:	learn: 0.4785315	total: 6.85s	remaining: 43.1s
# 137:	learn: 0.4784255	total: 6.89s	remaining: 43s
# 138:	learn: 0.4783313	total: 6.93s	remaining: 42.9s
# 139:	learn: 0.4782479	total: 6.96s	remaining: 42.8s
# 140:	learn: 0.4781595	total: 7s	remaining: 42.6s
# 141:	learn: 0.4780601	total: 7.15s	remaining: 43.2s
# 142:	learn: 0.4779595	total: 7.21s	remaining: 43.2s
# 143:	learn: 0.4779074	total: 7.26s	remaining: 43.2s
# 144:	learn: 0.4778494	total: 7.33s	remaining: 43.2s
# 145:	learn: 0.4777494	total: 7.41s	remaining: 43.3s
# 146:	learn: 0.4776875	total: 7.48s	remaining: 43.4s
# 147:	learn: 0.4775851	total: 7.54s	remaining: 43.4s
# 148:	learn: 0.4775023	total: 7.61s	remaining: 43.5s
# 149:	learn: 0.4774453	total: 7.67s	remaining: 43.5s
# 150:	learn: 0.4773309	total: 7.75s	remaining: 43.6s
# 151:	learn: 0.4772120	total: 7.83s	remaining: 43.7s
# 152:	learn: 0.4771486	total: 7.89s	remaining: 43.7s
# 153:	learn: 0.4770845	total: 7.92s	remaining: 43.5s
# 154:	learn: 0.4770357	total: 7.96s	remaining: 43.4s
# 155:	learn: 0.4769870	total: 8s	remaining: 43.3s
# 156:	learn: 0.4768906	total: 8.06s	remaining: 43.3s
# 157:	learn: 0.4767864	total: 8.13s	remaining: 43.4s
# 158:	learn: 0.4767557	total: 8.2s	remaining: 43.4s
# 159:	learn: 0.4766310	total: 8.27s	remaining: 43.4s
# 160:	learn: 0.4765316	total: 8.3s	remaining: 43.3s
# 161:	learn: 0.4764484	total: 8.35s	remaining: 43.2s
# 162:	learn: 0.4763674	total: 8.5s	remaining: 43.6s
# 163:	learn: 0.4763299	total: 8.56s	remaining: 43.6s
# 164:	learn: 0.4762692	total: 8.59s	remaining: 43.5s
# 165:	learn: 0.4761997	total: 8.63s	remaining: 43.3s
# 166:	learn: 0.4761264	total: 8.66s	remaining: 43.2s
# 167:	learn: 0.4760309	total: 8.7s	remaining: 43.1s
# 168:	learn: 0.4759637	total: 8.76s	remaining: 43.1s
# 169:	learn: 0.4758398	total: 8.87s	remaining: 43.3s
# 170:	learn: 0.4757346	total: 8.96s	remaining: 43.4s
# 171:	learn: 0.4756668	total: 9.03s	remaining: 43.5s
# 172:	learn: 0.4756181	total: 9.09s	remaining: 43.5s
# 173:	learn: 0.4755159	total: 9.15s	remaining: 43.5s
# 174:	learn: 0.4754549	total: 9.3s	remaining: 43.9s
# 175:	learn: 0.4753691	total: 9.4s	remaining: 44s
# 176:	learn: 0.4753052	total: 9.54s	remaining: 44.3s
# 177:	learn: 0.4751874	total: 9.65s	remaining: 44.5s
# 178:	learn: 0.4750919	total: 9.84s	remaining: 45.1s
# 179:	learn: 0.4750015	total: 9.99s	remaining: 45.5s
# 180:	learn: 0.4749049	total: 10.2s	remaining: 46.2s
# 181:	learn: 0.4748796	total: 10.4s	remaining: 46.5s
# 182:	learn: 0.4747754	total: 10.5s	remaining: 47s
# 183:	learn: 0.4747378	total: 10.6s	remaining: 47.2s
# 184:	learn: 0.4746528	total: 10.8s	remaining: 47.4s
# 185:	learn: 0.4745861	total: 10.9s	remaining: 47.8s
# 186:	learn: 0.4745163	total: 11.1s	remaining: 48.2s
# 187:	learn: 0.4744376	total: 11.2s	remaining: 48.3s
# 188:	learn: 0.4743626	total: 11.3s	remaining: 48.3s
# 189:	learn: 0.4742743	total: 11.4s	remaining: 48.7s
# 190:	learn: 0.4741746	total: 11.6s	remaining: 49.2s
# 191:	learn: 0.4741005	total: 11.7s	remaining: 49.4s
# 192:	learn: 0.4739601	total: 11.8s	remaining: 49.5s
# 193:	learn: 0.4738589	total: 12s	remaining: 49.7s
# 194:	learn: 0.4738423	total: 12s	remaining: 49.6s
# 195:	learn: 0.4737781	total: 12.1s	remaining: 49.6s
# 196:	learn: 0.4736776	total: 12.2s	remaining: 49.7s
# 197:	learn: 0.4735910	total: 12.3s	remaining: 50s
# 198:	learn: 0.4735526	total: 12.5s	remaining: 50.3s
# 199:	learn: 0.4734916	total: 12.7s	remaining: 50.7s
# 200:	learn: 0.4733980	total: 12.8s	remaining: 51.1s
# 201:	learn: 0.4733773	total: 12.9s	remaining: 51s
# 202:	learn: 0.4733432	total: 13s	remaining: 50.9s
# 203:	learn: 0.4733106	total: 13.1s	remaining: 51.1s
# 204:	learn: 0.4731498	total: 13.2s	remaining: 51.2s
# 205:	learn: 0.4731256	total: 13.3s	remaining: 51.3s
# 206:	learn: 0.4730551	total: 13.4s	remaining: 51.4s
# 207:	learn: 0.4729869	total: 13.5s	remaining: 51.4s
# 208:	learn: 0.4729097	total: 13.6s	remaining: 51.5s
# 209:	learn: 0.4728439	total: 13.7s	remaining: 51.6s
# 210:	learn: 0.4727748	total: 13.8s	remaining: 51.7s
# 211:	learn: 0.4727356	total: 14s	remaining: 51.9s
# 212:	learn: 0.4726473	total: 14.1s	remaining: 52.3s
# 213:	learn: 0.4725890	total: 14.3s	remaining: 52.5s
# 214:	learn: 0.4724919	total: 14.5s	remaining: 52.8s
# 215:	learn: 0.4724091	total: 14.6s	remaining: 53s
# 216:	learn: 0.4723512	total: 14.7s	remaining: 53.2s
# 217:	learn: 0.4723160	total: 14.8s	remaining: 53.2s
# 218:	learn: 0.4722435	total: 14.9s	remaining: 53.3s
# 219:	learn: 0.4722079	total: 15.1s	remaining: 53.4s
# 220:	learn: 0.4721743	total: 15.2s	remaining: 53.6s
# 221:	learn: 0.4721011	total: 15.4s	remaining: 53.8s
# 222:	learn: 0.4720034	total: 15.4s	remaining: 53.8s
# 223:	learn: 0.4719126	total: 15.5s	remaining: 53.8s
# 224:	learn: 0.4718516	total: 15.6s	remaining: 53.9s
# 225:	learn: 0.4717681	total: 15.7s	remaining: 53.8s
# 226:	learn: 0.4716993	total: 15.8s	remaining: 53.8s
# 227:	learn: 0.4716118	total: 15.9s	remaining: 53.9s
# 228:	learn: 0.4715354	total: 16.1s	remaining: 54.1s
# 229:	learn: 0.4714877	total: 16.2s	remaining: 54.1s
# 230:	learn: 0.4714224	total: 16.3s	remaining: 54.3s
# 231:	learn: 0.4713818	total: 16.5s	remaining: 54.5s
# 232:	learn: 0.4713523	total: 16.6s	remaining: 54.5s
# 233:	learn: 0.4713076	total: 16.7s	remaining: 54.6s
# 234:	learn: 0.4712567	total: 16.8s	remaining: 54.7s
# 235:	learn: 0.4711832	total: 16.9s	remaining: 54.7s
# 236:	learn: 0.4710949	total: 17s	remaining: 54.6s
# 237:	learn: 0.4710049	total: 17.1s	remaining: 54.6s
# 238:	learn: 0.4709208	total: 17.1s	remaining: 54.6s
# 239:	learn: 0.4708152	total: 17.2s	remaining: 54.6s
# 240:	learn: 0.4707392	total: 17.4s	remaining: 54.6s
# 241:	learn: 0.4706923	total: 17.4s	remaining: 54.6s
# 242:	learn: 0.4706099	total: 17.5s	remaining: 54.6s
# 243:	learn: 0.4705617	total: 17.6s	remaining: 54.5s
# 244:	learn: 0.4704780	total: 17.7s	remaining: 54.4s
# 245:	learn: 0.4703992	total: 17.7s	remaining: 54.3s
# 246:	learn: 0.4703202	total: 17.8s	remaining: 54.3s
# 247:	learn: 0.4702132	total: 17.9s	remaining: 54.2s
# 248:	learn: 0.4701186	total: 18s	remaining: 54.4s
# 249:	learn: 0.4700566	total: 18.2s	remaining: 54.5s
# 250:	learn: 0.4700166	total: 18.2s	remaining: 54.5s
# 251:	learn: 0.4699691	total: 18.4s	remaining: 54.5s
# 252:	learn: 0.4699269	total: 18.5s	remaining: 54.5s
# 253:	learn: 0.4698501	total: 18.6s	remaining: 54.7s
# 254:	learn: 0.4697855	total: 18.7s	remaining: 54.7s
# 255:	learn: 0.4697450	total: 18.8s	remaining: 54.8s
# 256:	learn: 0.4696632	total: 18.9s	remaining: 54.8s
# 257:	learn: 0.4696225	total: 19.1s	remaining: 54.8s
# 258:	learn: 0.4695104	total: 19.2s	remaining: 54.8s
# 259:	learn: 0.4694424	total: 19.2s	remaining: 54.8s
# 260:	learn: 0.4693442	total: 19.4s	remaining: 54.8s
# 261:	learn: 0.4693252	total: 19.4s	remaining: 54.8s
# 262:	learn: 0.4692870	total: 19.6s	remaining: 54.8s
# 263:	learn: 0.4692372	total: 19.7s	remaining: 54.9s
# 264:	learn: 0.4691448	total: 19.8s	remaining: 54.9s
# 265:	learn: 0.4690570	total: 19.9s	remaining: 54.8s
# 266:	learn: 0.4690326	total: 19.9s	remaining: 54.7s
# 267:	learn: 0.4689770	total: 20s	remaining: 54.7s
# 268:	learn: 0.4689380	total: 20.1s	remaining: 54.5s
# 269:	learn: 0.4688486	total: 20.1s	remaining: 54.4s
# 270:	learn: 0.4688131	total: 20.3s	remaining: 54.5s
# 271:	learn: 0.4687396	total: 20.4s	remaining: 54.5s
# 272:	learn: 0.4686729	total: 20.4s	remaining: 54.4s
# 273:	learn: 0.4686131	total: 20.5s	remaining: 54.4s
# 274:	learn: 0.4685418	total: 20.6s	remaining: 54.4s
# 275:	learn: 0.4685099	total: 20.7s	remaining: 54.4s
# 276:	learn: 0.4684449	total: 20.8s	remaining: 54.4s
# 277:	learn: 0.4683770	total: 20.9s	remaining: 54.3s
# 278:	learn: 0.4683229	total: 21s	remaining: 54.4s
# 279:	learn: 0.4682714	total: 21.1s	remaining: 54.4s
# 280:	learn: 0.4682324	total: 21.2s	remaining: 54.3s
# 281:	learn: 0.4681943	total: 21.3s	remaining: 54.3s
# 282:	learn: 0.4681311	total: 21.5s	remaining: 54.4s
# 283:	learn: 0.4680834	total: 21.6s	remaining: 54.5s
# 284:	learn: 0.4680216	total: 21.7s	remaining: 54.5s
# 285:	learn: 0.4679710	total: 21.8s	remaining: 54.4s
# 286:	learn: 0.4679029	total: 21.9s	remaining: 54.5s
# 287:	learn: 0.4678161	total: 22s	remaining: 54.4s
# 288:	learn: 0.4677631	total: 22.1s	remaining: 54.3s
# 289:	learn: 0.4676930	total: 22.1s	remaining: 54.2s
# 290:	learn: 0.4676460	total: 22.2s	remaining: 54s
# 291:	learn: 0.4675733	total: 22.3s	remaining: 54s
# 292:	learn: 0.4674836	total: 22.4s	remaining: 54s
# 293:	learn: 0.4674553	total: 22.5s	remaining: 54.1s
# 294:	learn: 0.4674249	total: 22.6s	remaining: 54.1s
# 295:	learn: 0.4673534	total: 22.8s	remaining: 54.2s
# 296:	learn: 0.4672836	total: 22.9s	remaining: 54.3s
# 297:	learn: 0.4671860	total: 23.1s	remaining: 54.5s
# 298:	learn: 0.4671645	total: 23.2s	remaining: 54.5s
# 299:	learn: 0.4670977	total: 23.4s	remaining: 54.6s
# 300:	learn: 0.4670410	total: 23.5s	remaining: 54.6s
# 301:	learn: 0.4669766	total: 23.8s	remaining: 55s
# 302:	learn: 0.4669102	total: 24.1s	remaining: 55.3s
# 303:	learn: 0.4668418	total: 24.3s	remaining: 55.6s
# 304:	learn: 0.4667659	total: 24.6s	remaining: 56s
# 305:	learn: 0.4667109	total: 24.8s	remaining: 56.2s
# 306:	learn: 0.4666900	total: 25s	remaining: 56.3s
# 307:	learn: 0.4666478	total: 25.1s	remaining: 56.4s
# 308:	learn: 0.4665773	total: 25.3s	remaining: 56.5s
# 309:	learn: 0.4665343	total: 25.5s	remaining: 56.7s
# 310:	learn: 0.4664438	total: 25.6s	remaining: 56.8s
# 311:	learn: 0.4663893	total: 25.8s	remaining: 56.9s
# 312:	learn: 0.4663455	total: 25.9s	remaining: 56.8s
# 313:	learn: 0.4663032	total: 26s	remaining: 56.7s
# 314:	learn: 0.4662763	total: 26s	remaining: 56.6s
# 315:	learn: 0.4662070	total: 26.1s	remaining: 56.4s
# 316:	learn: 0.4661799	total: 26.1s	remaining: 56.3s
# 317:	learn: 0.4661209	total: 26.2s	remaining: 56.2s
# 318:	learn: 0.4660705	total: 26.3s	remaining: 56.2s
# 319:	learn: 0.4660222	total: 26.4s	remaining: 56.2s
# 320:	learn: 0.4659777	total: 26.6s	remaining: 56.2s
# 321:	learn: 0.4659159	total: 26.7s	remaining: 56.2s
# 322:	learn: 0.4658685	total: 26.8s	remaining: 56.2s
# 323:	learn: 0.4658068	total: 26.9s	remaining: 56.2s
# 324:	learn: 0.4657273	total: 27.1s	remaining: 56.2s
# 325:	learn: 0.4656800	total: 27.2s	remaining: 56.3s
# 326:	learn: 0.4656283	total: 27.3s	remaining: 56.1s
# 327:	learn: 0.4655685	total: 27.4s	remaining: 56.1s
# 328:	learn: 0.4655136	total: 27.5s	remaining: 56.1s
# 329:	learn: 0.4654565	total: 27.6s	remaining: 56.1s
# 330:	learn: 0.4654078	total: 27.7s	remaining: 56s
# 331:	learn: 0.4653683	total: 27.8s	remaining: 56s
# 332:	learn: 0.4653402	total: 27.9s	remaining: 55.9s
# 333:	learn: 0.4653000	total: 27.9s	remaining: 55.7s
# 334:	learn: 0.4652554	total: 28s	remaining: 55.6s
# 335:	learn: 0.4651852	total: 28.1s	remaining: 55.5s
# 336:	learn: 0.4651503	total: 28.1s	remaining: 55.3s
# 337:	learn: 0.4650872	total: 28.2s	remaining: 55.3s
# 338:	learn: 0.4650467	total: 28.3s	remaining: 55.2s
# 339:	learn: 0.4649465	total: 28.5s	remaining: 55.3s
# 340:	learn: 0.4649144	total: 28.6s	remaining: 55.3s
# 341:	learn: 0.4648803	total: 28.7s	remaining: 55.3s
# 342:	learn: 0.4647695	total: 28.9s	remaining: 55.3s
# 343:	learn: 0.4647409	total: 29.1s	remaining: 55.4s
# 344:	learn: 0.4646991	total: 29.2s	remaining: 55.4s
# 345:	learn: 0.4646751	total: 29.3s	remaining: 55.4s
# 346:	learn: 0.4646292	total: 29.4s	remaining: 55.3s
# 347:	learn: 0.4645829	total: 29.5s	remaining: 55.4s
# 348:	learn: 0.4645480	total: 29.7s	remaining: 55.4s
# 349:	learn: 0.4645271	total: 29.8s	remaining: 55.3s
# 350:	learn: 0.4644837	total: 30s	remaining: 55.4s
# 351:	learn: 0.4643946	total: 30.1s	remaining: 55.4s
# 352:	learn: 0.4643446	total: 30.3s	remaining: 55.5s
# 353:	learn: 0.4642703	total: 30.4s	remaining: 55.4s
# 354:	learn: 0.4642062	total: 30.5s	remaining: 55.4s
# 355:	learn: 0.4641419	total: 30.6s	remaining: 55.3s
# 356:	learn: 0.4640656	total: 30.6s	remaining: 55.2s
# 357:	learn: 0.4640323	total: 30.7s	remaining: 55.1s
# 358:	learn: 0.4639906	total: 30.8s	remaining: 55s
# 359:	learn: 0.4639363	total: 31s	remaining: 55.1s
# 360:	learn: 0.4638713	total: 31.1s	remaining: 55.1s
# 361:	learn: 0.4638418	total: 31.2s	remaining: 55s
# 362:	learn: 0.4637877	total: 31.3s	remaining: 55s
# 363:	learn: 0.4637694	total: 31.4s	remaining: 54.9s
# 364:	learn: 0.4637180	total: 31.5s	remaining: 54.8s
# 365:	learn: 0.4636575	total: 31.6s	remaining: 54.7s
# 366:	learn: 0.4636400	total: 31.7s	remaining: 54.7s
# 367:	learn: 0.4635742	total: 31.8s	remaining: 54.6s
# 368:	learn: 0.4635397	total: 32s	remaining: 54.7s
# 369:	learn: 0.4635038	total: 32.1s	remaining: 54.6s
# 370:	learn: 0.4634524	total: 32.2s	remaining: 54.6s
# 371:	learn: 0.4634084	total: 32.3s	remaining: 54.5s
# 372:	learn: 0.4633821	total: 32.4s	remaining: 54.4s
# 373:	learn: 0.4633692	total: 32.5s	remaining: 54.4s
# 374:	learn: 0.4632943	total: 32.7s	remaining: 54.4s
# 375:	learn: 0.4632592	total: 32.8s	remaining: 54.4s
# 376:	learn: 0.4632272	total: 32.9s	remaining: 54.3s
# 377:	learn: 0.4631874	total: 32.9s	remaining: 54.2s
# 378:	learn: 0.4631465	total: 33s	remaining: 54.1s
# 379:	learn: 0.4630998	total: 33.1s	remaining: 54.1s
# 380:	learn: 0.4630469	total: 33.3s	remaining: 54s
# 381:	learn: 0.4630228	total: 33.4s	remaining: 54s
# 382:	learn: 0.4629971	total: 33.5s	remaining: 53.9s
# 383:	learn: 0.4629038	total: 33.6s	remaining: 53.8s
# 384:	learn: 0.4628443	total: 33.6s	remaining: 53.7s
# 385:	learn: 0.4627861	total: 33.8s	remaining: 53.7s
# 386:	learn: 0.4627413	total: 33.9s	remaining: 53.6s
# 387:	learn: 0.4627043	total: 33.9s	remaining: 53.5s
# 388:	learn: 0.4626333	total: 34.1s	remaining: 53.6s
# 389:	learn: 0.4625795	total: 34.2s	remaining: 53.6s
# 390:	learn: 0.4625434	total: 34.4s	remaining: 53.5s
# 391:	learn: 0.4625048	total: 34.5s	remaining: 53.5s
# 392:	learn: 0.4624700	total: 34.6s	remaining: 53.5s
# 393:	learn: 0.4624390	total: 34.7s	remaining: 53.4s
# 394:	learn: 0.4623932	total: 34.8s	remaining: 53.3s
# 395:	learn: 0.4623664	total: 34.9s	remaining: 53.2s
# 396:	learn: 0.4623190	total: 34.9s	remaining: 53.1s
# 397:	learn: 0.4622979	total: 35s	remaining: 53s
# 398:	learn: 0.4622608	total: 35.1s	remaining: 52.8s
# 399:	learn: 0.4622385	total: 35.2s	remaining: 52.8s
# 400:	learn: 0.4621550	total: 35.2s	remaining: 52.6s
# 401:	learn: 0.4621197	total: 35.3s	remaining: 52.5s
# 402:	learn: 0.4620899	total: 35.3s	remaining: 52.3s
# 403:	learn: 0.4620594	total: 35.4s	remaining: 52.2s
# 404:	learn: 0.4620323	total: 35.4s	remaining: 52.1s
# 405:	learn: 0.4619656	total: 35.5s	remaining: 52s
# 406:	learn: 0.4619430	total: 35.6s	remaining: 51.9s
# 407:	learn: 0.4618923	total: 35.7s	remaining: 51.8s
# 408:	learn: 0.4618561	total: 35.8s	remaining: 51.7s
# 409:	learn: 0.4618014	total: 35.9s	remaining: 51.6s
# 410:	learn: 0.4617691	total: 36s	remaining: 51.5s
# 411:	learn: 0.4617282	total: 36.1s	remaining: 51.5s
# 412:	learn: 0.4617068	total: 36.2s	remaining: 51.4s
# 413:	learn: 0.4616738	total: 36.3s	remaining: 51.4s
# 414:	learn: 0.4616327	total: 36.4s	remaining: 51.3s
# 415:	learn: 0.4615990	total: 36.6s	remaining: 51.3s
# 416:	learn: 0.4615694	total: 36.7s	remaining: 51.2s
# 417:	learn: 0.4615043	total: 36.7s	remaining: 51.2s
# 418:	learn: 0.4614680	total: 36.9s	remaining: 51.1s
# 419:	learn: 0.4614326	total: 37s	remaining: 51.1s
# 420:	learn: 0.4613967	total: 37.2s	remaining: 51.1s
# 421:	learn: 0.4613438	total: 37.3s	remaining: 51.1s
# 422:	learn: 0.4613136	total: 37.5s	remaining: 51.1s
# 423:	learn: 0.4612809	total: 37.6s	remaining: 51s
# 424:	learn: 0.4612260	total: 37.7s	remaining: 51s
# 425:	learn: 0.4611871	total: 37.8s	remaining: 50.9s
# 426:	learn: 0.4611217	total: 37.9s	remaining: 50.9s
# 427:	learn: 0.4610991	total: 38s	remaining: 50.8s
# 428:	learn: 0.4610582	total: 38.1s	remaining: 50.7s
# 429:	learn: 0.4610301	total: 38.2s	remaining: 50.6s
# 430:	learn: 0.4609914	total: 38.3s	remaining: 50.5s
# 431:	learn: 0.4609671	total: 38.3s	remaining: 50.4s
# 432:	learn: 0.4609597	total: 38.4s	remaining: 50.3s
# 433:	learn: 0.4608674	total: 38.4s	remaining: 50.1s
# 434:	learn: 0.4608404	total: 38.5s	remaining: 50s
# 435:	learn: 0.4608287	total: 38.5s	remaining: 49.9s
# 436:	learn: 0.4607971	total: 38.6s	remaining: 49.7s
# 437:	learn: 0.4607274	total: 38.7s	remaining: 49.6s
# 438:	learn: 0.4607182	total: 38.7s	remaining: 49.5s
# 439:	learn: 0.4606895	total: 38.8s	remaining: 49.4s
# 440:	learn: 0.4606557	total: 38.8s	remaining: 49.2s
# 441:	learn: 0.4606246	total: 38.8s	remaining: 49s
# 442:	learn: 0.4605875	total: 38.9s	remaining: 48.9s
# 443:	learn: 0.4605279	total: 38.9s	remaining: 48.7s
# 444:	learn: 0.4604929	total: 38.9s	remaining: 48.6s
# 445:	learn: 0.4604599	total: 39s	remaining: 48.4s
# 446:	learn: 0.4604354	total: 39s	remaining: 48.2s
# 447:	learn: 0.4604145	total: 39s	remaining: 48.1s
# 448:	learn: 0.4603891	total: 39s	remaining: 47.9s
# 449:	learn: 0.4603472	total: 39.1s	remaining: 47.8s
# 450:	learn: 0.4603076	total: 39.1s	remaining: 47.6s
# 451:	learn: 0.4602635	total: 39.1s	remaining: 47.4s
# 452:	learn: 0.4602096	total: 39.2s	remaining: 47.3s
# 453:	learn: 0.4601614	total: 39.2s	remaining: 47.1s
# 454:	learn: 0.4601232	total: 39.2s	remaining: 47s
# 455:	learn: 0.4600881	total: 39.2s	remaining: 46.8s
# 456:	learn: 0.4600604	total: 39.3s	remaining: 46.7s
# 457:	learn: 0.4600190	total: 39.3s	remaining: 46.5s
# 458:	learn: 0.4599467	total: 39.3s	remaining: 46.4s
# 459:	learn: 0.4599214	total: 39.4s	remaining: 46.2s
# 460:	learn: 0.4598887	total: 39.4s	remaining: 46.1s
# 461:	learn: 0.4598674	total: 39.4s	remaining: 45.9s
# 462:	learn: 0.4598242	total: 39.5s	remaining: 45.8s
# 463:	learn: 0.4597816	total: 39.5s	remaining: 45.6s
# 464:	learn: 0.4597324	total: 39.5s	remaining: 45.5s
# 465:	learn: 0.4597075	total: 39.5s	remaining: 45.3s
# 466:	learn: 0.4596752	total: 39.6s	remaining: 45.2s
# 467:	learn: 0.4596107	total: 39.6s	remaining: 45s
# 468:	learn: 0.4595545	total: 39.6s	remaining: 44.9s
# 469:	learn: 0.4594925	total: 39.7s	remaining: 44.7s
# 470:	learn: 0.4594613	total: 39.7s	remaining: 44.6s
# 471:	learn: 0.4594373	total: 39.7s	remaining: 44.4s
# 472:	learn: 0.4594180	total: 39.7s	remaining: 44.3s
# 473:	learn: 0.4593761	total: 39.8s	remaining: 44.1s
# 474:	learn: 0.4593227	total: 39.8s	remaining: 44s
# 475:	learn: 0.4592902	total: 39.8s	remaining: 43.8s
# 476:	learn: 0.4592679	total: 39.8s	remaining: 43.7s
# 477:	learn: 0.4592452	total: 39.9s	remaining: 43.5s
# 478:	learn: 0.4592074	total: 39.9s	remaining: 43.4s
# 479:	learn: 0.4591819	total: 39.9s	remaining: 43.3s
# 480:	learn: 0.4591423	total: 40s	remaining: 43.1s
# 481:	learn: 0.4590973	total: 40s	remaining: 43s
# 482:	learn: 0.4590818	total: 40s	remaining: 42.8s
# 483:	learn: 0.4590438	total: 40s	remaining: 42.7s
# 484:	learn: 0.4590173	total: 40.1s	remaining: 42.6s
# 485:	learn: 0.4589946	total: 40.1s	remaining: 42.4s
# 486:	learn: 0.4589903	total: 40.1s	remaining: 42.3s
# 487:	learn: 0.4589696	total: 40.2s	remaining: 42.1s
# 488:	learn: 0.4589029	total: 40.2s	remaining: 42s
# 489:	learn: 0.4588837	total: 40.2s	remaining: 41.8s
# 490:	learn: 0.4588198	total: 40.2s	remaining: 41.7s
# 491:	learn: 0.4587702	total: 40.3s	remaining: 41.6s
# 492:	learn: 0.4587585	total: 40.3s	remaining: 41.5s
# 493:	learn: 0.4587317	total: 40.4s	remaining: 41.4s
# 494:	learn: 0.4586790	total: 40.4s	remaining: 41.2s
# 495:	learn: 0.4586446	total: 40.4s	remaining: 41.1s
# 496:	learn: 0.4586107	total: 40.5s	remaining: 41s
# 497:	learn: 0.4585922	total: 40.5s	remaining: 40.8s
# 498:	learn: 0.4585669	total: 40.5s	remaining: 40.7s
# 499:	learn: 0.4585515	total: 40.5s	remaining: 40.5s
# 500:	learn: 0.4584932	total: 40.6s	remaining: 40.4s
# 501:	learn: 0.4584568	total: 40.6s	remaining: 40.3s
# 502:	learn: 0.4584279	total: 40.6s	remaining: 40.1s
# 503:	learn: 0.4583838	total: 40.7s	remaining: 40s
# 504:	learn: 0.4583437	total: 40.7s	remaining: 39.9s
# 505:	learn: 0.4582901	total: 40.7s	remaining: 39.8s
# 506:	learn: 0.4582659	total: 40.7s	remaining: 39.6s
# 507:	learn: 0.4582305	total: 40.8s	remaining: 39.5s
# 508:	learn: 0.4581901	total: 40.8s	remaining: 39.4s
# 509:	learn: 0.4581812	total: 40.8s	remaining: 39.2s
# 510:	learn: 0.4581442	total: 40.9s	remaining: 39.1s
# 511:	learn: 0.4581150	total: 40.9s	remaining: 39s
# 512:	learn: 0.4580529	total: 40.9s	remaining: 38.8s
# 513:	learn: 0.4580401	total: 40.9s	remaining: 38.7s
# 514:	learn: 0.4580164	total: 41s	remaining: 38.6s
# 515:	learn: 0.4579996	total: 41s	remaining: 38.5s
# 516:	learn: 0.4579706	total: 41s	remaining: 38.3s
# 517:	learn: 0.4579417	total: 41s	remaining: 38.2s
# 518:	learn: 0.4579205	total: 41.1s	remaining: 38.1s
# 519:	learn: 0.4578881	total: 41.1s	remaining: 37.9s
# 520:	learn: 0.4578793	total: 41.1s	remaining: 37.8s
# 521:	learn: 0.4578661	total: 41.2s	remaining: 37.7s
# 522:	learn: 0.4578478	total: 41.2s	remaining: 37.6s
# 523:	learn: 0.4578378	total: 41.2s	remaining: 37.4s
# 524:	learn: 0.4578191	total: 41.2s	remaining: 37.3s
# 525:	learn: 0.4577917	total: 41.3s	remaining: 37.2s
# 526:	learn: 0.4577380	total: 41.3s	remaining: 37.1s
# 527:	learn: 0.4576915	total: 41.3s	remaining: 37s
# 528:	learn: 0.4576670	total: 41.4s	remaining: 36.8s
# 529:	learn: 0.4576518	total: 41.4s	remaining: 36.7s
# 530:	learn: 0.4576297	total: 41.4s	remaining: 36.6s
# 531:	learn: 0.4575711	total: 41.5s	remaining: 36.5s
# 532:	learn: 0.4575522	total: 41.5s	remaining: 36.4s
# 533:	learn: 0.4575452	total: 41.5s	remaining: 36.2s
# 534:	learn: 0.4574933	total: 41.5s	remaining: 36.1s
# 535:	learn: 0.4574723	total: 41.6s	remaining: 36s
# 536:	learn: 0.4574607	total: 41.6s	remaining: 35.9s
# 537:	learn: 0.4574371	total: 41.6s	remaining: 35.7s
# 538:	learn: 0.4574019	total: 41.7s	remaining: 35.6s
# 539:	learn: 0.4573431	total: 41.7s	remaining: 35.5s
# 540:	learn: 0.4573274	total: 41.7s	remaining: 35.4s
# 541:	learn: 0.4573179	total: 41.7s	remaining: 35.3s
# 542:	learn: 0.4572778	total: 41.8s	remaining: 35.1s
# 543:	learn: 0.4572652	total: 41.8s	remaining: 35s
# 544:	learn: 0.4572209	total: 41.8s	remaining: 34.9s
# 545:	learn: 0.4571723	total: 41.8s	remaining: 34.8s
# 546:	learn: 0.4571389	total: 41.9s	remaining: 34.7s
# 547:	learn: 0.4570954	total: 41.9s	remaining: 34.6s
# 548:	learn: 0.4570615	total: 41.9s	remaining: 34.4s
# 549:	learn: 0.4570552	total: 42s	remaining: 34.3s
# 550:	learn: 0.4570166	total: 42s	remaining: 34.2s
# 551:	learn: 0.4569766	total: 42s	remaining: 34.1s
# 552:	learn: 0.4569713	total: 42s	remaining: 34s
# 553:	learn: 0.4569487	total: 42.1s	remaining: 33.9s
# 554:	learn: 0.4569364	total: 42.1s	remaining: 33.8s
# 555:	learn: 0.4569074	total: 42.1s	remaining: 33.6s
# 556:	learn: 0.4568702	total: 42.2s	remaining: 33.5s
# 557:	learn: 0.4568353	total: 42.2s	remaining: 33.4s
# 558:	learn: 0.4567893	total: 42.2s	remaining: 33.3s
# 559:	learn: 0.4567614	total: 42.3s	remaining: 33.2s
# 560:	learn: 0.4567358	total: 42.3s	remaining: 33.1s
# 561:	learn: 0.4567072	total: 42.3s	remaining: 33s
# 562:	learn: 0.4566775	total: 42.3s	remaining: 32.9s
# 563:	learn: 0.4566562	total: 42.4s	remaining: 32.8s
# 564:	learn: 0.4566164	total: 42.4s	remaining: 32.6s
# 565:	learn: 0.4565924	total: 42.4s	remaining: 32.5s
# 566:	learn: 0.4565439	total: 42.5s	remaining: 32.4s
# 567:	learn: 0.4565170	total: 42.5s	remaining: 32.3s
# 568:	learn: 0.4564920	total: 42.5s	remaining: 32.2s
# 569:	learn: 0.4564579	total: 42.5s	remaining: 32.1s
# 570:	learn: 0.4564331	total: 42.6s	remaining: 32s
# 571:	learn: 0.4563953	total: 42.6s	remaining: 31.9s
# 572:	learn: 0.4563694	total: 42.6s	remaining: 31.8s
# 573:	learn: 0.4563576	total: 42.7s	remaining: 31.7s
# 574:	learn: 0.4563486	total: 42.7s	remaining: 31.5s
# 575:	learn: 0.4562993	total: 42.7s	remaining: 31.4s
# 576:	learn: 0.4562605	total: 42.7s	remaining: 31.3s
# 577:	learn: 0.4562320	total: 42.8s	remaining: 31.2s
# 578:	learn: 0.4562165	total: 42.8s	remaining: 31.1s
# 579:	learn: 0.4561796	total: 42.8s	remaining: 31s
# 580:	learn: 0.4561280	total: 42.9s	remaining: 30.9s
# 581:	learn: 0.4561010	total: 42.9s	remaining: 30.8s
# 582:	learn: 0.4560731	total: 42.9s	remaining: 30.7s
# 583:	learn: 0.4560510	total: 42.9s	remaining: 30.6s
# 584:	learn: 0.4560378	total: 43s	remaining: 30.5s
# 585:	learn: 0.4559984	total: 43s	remaining: 30.4s
# 586:	learn: 0.4559776	total: 43s	remaining: 30.3s
# 587:	learn: 0.4559562	total: 43s	remaining: 30.2s
# 588:	learn: 0.4559164	total: 43.1s	remaining: 30.1s
# 589:	learn: 0.4559019	total: 43.1s	remaining: 30s
# 590:	learn: 0.4558514	total: 43.1s	remaining: 29.9s
# 591:	learn: 0.4557951	total: 43.2s	remaining: 29.7s
# 592:	learn: 0.4557820	total: 43.2s	remaining: 29.6s
# 593:	learn: 0.4557333	total: 43.2s	remaining: 29.5s
# 594:	learn: 0.4556757	total: 43.3s	remaining: 29.4s
# 595:	learn: 0.4556429	total: 43.3s	remaining: 29.3s
# 596:	learn: 0.4556327	total: 43.3s	remaining: 29.2s
# 597:	learn: 0.4555914	total: 43.4s	remaining: 29.2s
# 598:	learn: 0.4555733	total: 43.4s	remaining: 29s
# 599:	learn: 0.4555390	total: 43.4s	remaining: 28.9s
# 600:	learn: 0.4555128	total: 43.4s	remaining: 28.8s
# 601:	learn: 0.4554898	total: 43.5s	remaining: 28.7s
# 602:	learn: 0.4554802	total: 43.5s	remaining: 28.6s
# 603:	learn: 0.4554620	total: 43.5s	remaining: 28.5s
# 604:	learn: 0.4554287	total: 43.5s	remaining: 28.4s
# 605:	learn: 0.4554140	total: 43.6s	remaining: 28.3s
# 606:	learn: 0.4553908	total: 43.6s	remaining: 28.2s
# 607:	learn: 0.4553660	total: 43.6s	remaining: 28.1s
# 608:	learn: 0.4553253	total: 43.7s	remaining: 28s
# 609:	learn: 0.4553064	total: 43.7s	remaining: 27.9s
# 610:	learn: 0.4552987	total: 43.7s	remaining: 27.8s
# 611:	learn: 0.4552636	total: 43.7s	remaining: 27.7s
# 612:	learn: 0.4552561	total: 43.8s	remaining: 27.6s
# 613:	learn: 0.4552068	total: 43.8s	remaining: 27.5s
# 614:	learn: 0.4551870	total: 43.8s	remaining: 27.4s
# 615:	learn: 0.4551527	total: 43.8s	remaining: 27.3s
# 616:	learn: 0.4551301	total: 43.9s	remaining: 27.2s
# 617:	learn: 0.4551231	total: 43.9s	remaining: 27.1s
# 618:	learn: 0.4550937	total: 43.9s	remaining: 27s
# 619:	learn: 0.4550785	total: 44s	remaining: 26.9s
# 620:	learn: 0.4550552	total: 44s	remaining: 26.8s
# 621:	learn: 0.4550168	total: 44s	remaining: 26.7s
# 622:	learn: 0.4549786	total: 44s	remaining: 26.7s
# 623:	learn: 0.4549567	total: 44.1s	remaining: 26.6s
# 624:	learn: 0.4549246	total: 44.1s	remaining: 26.5s
# 625:	learn: 0.4549061	total: 44.1s	remaining: 26.4s
# 626:	learn: 0.4548758	total: 44.1s	remaining: 26.3s
# 627:	learn: 0.4548480	total: 44.2s	remaining: 26.2s
# 628:	learn: 0.4548382	total: 44.2s	remaining: 26.1s
# 629:	learn: 0.4548170	total: 44.2s	remaining: 26s
# 630:	learn: 0.4547925	total: 44.3s	remaining: 25.9s
# 631:	learn: 0.4547707	total: 44.3s	remaining: 25.8s
# 632:	learn: 0.4547688	total: 44.3s	remaining: 25.7s
# 633:	learn: 0.4547653	total: 44.3s	remaining: 25.6s
# 634:	learn: 0.4547544	total: 44.4s	remaining: 25.5s
# 635:	learn: 0.4547459	total: 44.4s	remaining: 25.4s
# 636:	learn: 0.4547026	total: 44.4s	remaining: 25.3s
# 637:	learn: 0.4546528	total: 44.5s	remaining: 25.2s
# 638:	learn: 0.4546356	total: 44.5s	remaining: 25.1s
# 639:	learn: 0.4545809	total: 44.5s	remaining: 25s
# 640:	learn: 0.4545619	total: 44.5s	remaining: 24.9s
# 641:	learn: 0.4545441	total: 44.6s	remaining: 24.9s
# 642:	learn: 0.4545323	total: 44.6s	remaining: 24.8s
# 643:	learn: 0.4544889	total: 44.6s	remaining: 24.7s
# 644:	learn: 0.4544775	total: 44.7s	remaining: 24.6s
# 645:	learn: 0.4544684	total: 44.7s	remaining: 24.5s
# 646:	learn: 0.4544586	total: 44.7s	remaining: 24.4s
# 647:	learn: 0.4544511	total: 44.7s	remaining: 24.3s
# 648:	learn: 0.4544010	total: 44.8s	remaining: 24.2s
# 649:	learn: 0.4543849	total: 44.8s	remaining: 24.1s
# 650:	learn: 0.4543680	total: 44.8s	remaining: 24s
# 651:	learn: 0.4543430	total: 44.9s	remaining: 23.9s
# 652:	learn: 0.4543129	total: 44.9s	remaining: 23.9s
# 653:	learn: 0.4542960	total: 44.9s	remaining: 23.8s
# 654:	learn: 0.4542888	total: 44.9s	remaining: 23.7s
# 655:	learn: 0.4542469	total: 45s	remaining: 23.6s
# 656:	learn: 0.4542223	total: 45s	remaining: 23.5s
# 657:	learn: 0.4542057	total: 45s	remaining: 23.4s
# 658:	learn: 0.4541843	total: 45.1s	remaining: 23.3s
# 659:	learn: 0.4541545	total: 45.1s	remaining: 23.2s
# 660:	learn: 0.4541221	total: 45.1s	remaining: 23.1s
# 661:	learn: 0.4541048	total: 45.1s	remaining: 23s
# 662:	learn: 0.4540931	total: 45.2s	remaining: 23s
# 663:	learn: 0.4540574	total: 45.2s	remaining: 22.9s
# 664:	learn: 0.4540283	total: 45.2s	remaining: 22.8s
# 665:	learn: 0.4540166	total: 45.3s	remaining: 22.7s
# 666:	learn: 0.4539934	total: 45.3s	remaining: 22.6s
# 667:	learn: 0.4539837	total: 45.3s	remaining: 22.5s
# 668:	learn: 0.4539614	total: 45.3s	remaining: 22.4s
# 669:	learn: 0.4539171	total: 45.4s	remaining: 22.3s
# 670:	learn: 0.4538913	total: 45.4s	remaining: 22.3s
# 671:	learn: 0.4538811	total: 45.4s	remaining: 22.2s
# 672:	learn: 0.4538538	total: 45.5s	remaining: 22.1s
# 673:	learn: 0.4538303	total: 45.5s	remaining: 22s
# 674:	learn: 0.4538109	total: 45.5s	remaining: 21.9s
# 675:	learn: 0.4537804	total: 45.6s	remaining: 21.8s
# 676:	learn: 0.4537641	total: 45.6s	remaining: 21.7s
# 677:	learn: 0.4537526	total: 45.6s	remaining: 21.7s
# 678:	learn: 0.4537328	total: 45.6s	remaining: 21.6s
# 679:	learn: 0.4536917	total: 45.7s	remaining: 21.5s
# 680:	learn: 0.4536533	total: 45.7s	remaining: 21.4s
# 681:	learn: 0.4536453	total: 45.7s	remaining: 21.3s
# 682:	learn: 0.4536332	total: 45.7s	remaining: 21.2s
# 683:	learn: 0.4536299	total: 45.8s	remaining: 21.1s
# 684:	learn: 0.4535836	total: 45.8s	remaining: 21.1s
# 685:	learn: 0.4535474	total: 45.8s	remaining: 21s
# 686:	learn: 0.4535308	total: 45.9s	remaining: 20.9s
# 687:	learn: 0.4535201	total: 45.9s	remaining: 20.8s
# 688:	learn: 0.4535078	total: 45.9s	remaining: 20.7s
# 689:	learn: 0.4534938	total: 45.9s	remaining: 20.6s
# 690:	learn: 0.4534725	total: 46s	remaining: 20.6s
# 691:	learn: 0.4534240	total: 46s	remaining: 20.5s
# 692:	learn: 0.4533787	total: 46s	remaining: 20.4s
# 693:	learn: 0.4533415	total: 46.1s	remaining: 20.3s
# 694:	learn: 0.4533116	total: 46.1s	remaining: 20.2s
# 695:	learn: 0.4532807	total: 46.1s	remaining: 20.1s
# 696:	learn: 0.4532574	total: 46.1s	remaining: 20.1s
# 697:	learn: 0.4532339	total: 46.2s	remaining: 20s
# 698:	learn: 0.4532210	total: 46.2s	remaining: 19.9s
# 699:	learn: 0.4531782	total: 46.2s	remaining: 19.8s
# 700:	learn: 0.4531515	total: 46.3s	remaining: 19.7s
# 701:	learn: 0.4531424	total: 46.3s	remaining: 19.6s
# 702:	learn: 0.4531149	total: 46.3s	remaining: 19.6s
# 703:	learn: 0.4530975	total: 46.3s	remaining: 19.5s
# 704:	learn: 0.4530716	total: 46.4s	remaining: 19.4s
# 705:	learn: 0.4530553	total: 46.4s	remaining: 19.3s
# 706:	learn: 0.4530352	total: 46.4s	remaining: 19.2s
# 707:	learn: 0.4530005	total: 46.5s	remaining: 19.2s
# 708:	learn: 0.4529909	total: 46.5s	remaining: 19.1s
# 709:	learn: 0.4529771	total: 46.5s	remaining: 19s
# 710:	learn: 0.4529632	total: 46.6s	remaining: 18.9s
# 711:	learn: 0.4529455	total: 46.6s	remaining: 18.8s
# 712:	learn: 0.4529204	total: 46.6s	remaining: 18.8s
# 713:	learn: 0.4529072	total: 46.6s	remaining: 18.7s
# 714:	learn: 0.4528892	total: 46.7s	remaining: 18.6s
# 715:	learn: 0.4528525	total: 46.7s	remaining: 18.5s
# 716:	learn: 0.4528125	total: 46.7s	remaining: 18.4s
# 717:	learn: 0.4527734	total: 46.7s	remaining: 18.4s
# 718:	learn: 0.4527546	total: 46.8s	remaining: 18.3s
# 719:	learn: 0.4527504	total: 46.8s	remaining: 18.2s
# 720:	learn: 0.4527240	total: 46.8s	remaining: 18.1s
# 721:	learn: 0.4526974	total: 46.9s	remaining: 18s
# 722:	learn: 0.4526627	total: 46.9s	remaining: 18s
# 723:	learn: 0.4526549	total: 46.9s	remaining: 17.9s
# 724:	learn: 0.4526347	total: 46.9s	remaining: 17.8s
# 725:	learn: 0.4526109	total: 47s	remaining: 17.7s
# 726:	learn: 0.4525674	total: 47s	remaining: 17.7s
# 727:	learn: 0.4525565	total: 47s	remaining: 17.6s
# 728:	learn: 0.4525426	total: 47.1s	remaining: 17.5s
# 729:	learn: 0.4525055	total: 47.1s	remaining: 17.4s
# 730:	learn: 0.4524802	total: 47.1s	remaining: 17.3s
# 731:	learn: 0.4524677	total: 47.2s	remaining: 17.3s
# 732:	learn: 0.4524495	total: 47.2s	remaining: 17.2s
# 733:	learn: 0.4524339	total: 47.2s	remaining: 17.1s
# 734:	learn: 0.4524023	total: 47.3s	remaining: 17s
# 735:	learn: 0.4523694	total: 47.3s	remaining: 17s
# 736:	learn: 0.4523471	total: 47.3s	remaining: 16.9s
# 737:	learn: 0.4523218	total: 47.3s	remaining: 16.8s
# 738:	learn: 0.4522967	total: 47.4s	remaining: 16.7s
# 739:	learn: 0.4522656	total: 47.4s	remaining: 16.7s
# 740:	learn: 0.4522241	total: 47.4s	remaining: 16.6s
# 741:	learn: 0.4521856	total: 47.5s	remaining: 16.5s
# 742:	learn: 0.4521555	total: 47.5s	remaining: 16.4s
# 743:	learn: 0.4521371	total: 47.5s	remaining: 16.4s
# 744:	learn: 0.4521292	total: 47.6s	remaining: 16.3s
# 745:	learn: 0.4521087	total: 47.6s	remaining: 16.2s
# 746:	learn: 0.4520915	total: 47.6s	remaining: 16.1s
# 747:	learn: 0.4520806	total: 47.6s	remaining: 16.1s
# 748:	learn: 0.4520554	total: 47.7s	remaining: 16s
# 749:	learn: 0.4520401	total: 47.7s	remaining: 15.9s
# 750:	learn: 0.4520264	total: 47.7s	remaining: 15.8s
# 751:	learn: 0.4520038	total: 47.7s	remaining: 15.7s
# 752:	learn: 0.4519765	total: 47.8s	remaining: 15.7s
# 753:	learn: 0.4519480	total: 47.8s	remaining: 15.6s
# 754:	learn: 0.4519310	total: 47.8s	remaining: 15.5s
# 755:	learn: 0.4519146	total: 47.9s	remaining: 15.4s
# 756:	learn: 0.4519078	total: 47.9s	remaining: 15.4s
# 757:	learn: 0.4518593	total: 47.9s	remaining: 15.3s
# 758:	learn: 0.4518487	total: 47.9s	remaining: 15.2s
# 759:	learn: 0.4518229	total: 48s	remaining: 15.2s
# 760:	learn: 0.4518075	total: 48s	remaining: 15.1s
# 761:	learn: 0.4517839	total: 48s	remaining: 15s
# 762:	learn: 0.4517671	total: 48.1s	remaining: 14.9s
# 763:	learn: 0.4517468	total: 48.1s	remaining: 14.9s
# 764:	learn: 0.4517366	total: 48.1s	remaining: 14.8s
# 765:	learn: 0.4517291	total: 48.1s	remaining: 14.7s
# 766:	learn: 0.4516985	total: 48.2s	remaining: 14.6s
# 767:	learn: 0.4516806	total: 48.2s	remaining: 14.6s
# 768:	learn: 0.4516681	total: 48.2s	remaining: 14.5s
# 769:	learn: 0.4516504	total: 48.3s	remaining: 14.4s
# 770:	learn: 0.4516249	total: 48.3s	remaining: 14.3s
# 771:	learn: 0.4515988	total: 48.3s	remaining: 14.3s
# 772:	learn: 0.4515753	total: 48.4s	remaining: 14.2s
# 773:	learn: 0.4515572	total: 48.4s	remaining: 14.1s
# 774:	learn: 0.4515359	total: 48.4s	remaining: 14.1s
# 775:	learn: 0.4515029	total: 48.4s	remaining: 14s
# 776:	learn: 0.4514988	total: 48.5s	remaining: 13.9s
# 777:	learn: 0.4514806	total: 48.5s	remaining: 13.8s
# 778:	learn: 0.4514532	total: 48.5s	remaining: 13.8s
# 779:	learn: 0.4514420	total: 48.6s	remaining: 13.7s
# 780:	learn: 0.4514227	total: 48.6s	remaining: 13.6s
# 781:	learn: 0.4514147	total: 48.6s	remaining: 13.6s
# 782:	learn: 0.4513821	total: 48.6s	remaining: 13.5s
# 783:	learn: 0.4513604	total: 48.7s	remaining: 13.4s
# 784:	learn: 0.4513451	total: 48.7s	remaining: 13.3s
# 785:	learn: 0.4513217	total: 48.8s	remaining: 13.3s
# 786:	learn: 0.4513065	total: 48.8s	remaining: 13.2s
# 787:	learn: 0.4512798	total: 48.9s	remaining: 13.2s
# 788:	learn: 0.4512686	total: 49s	remaining: 13.1s
# 789:	learn: 0.4512386	total: 49s	remaining: 13s
# 790:	learn: 0.4512060	total: 49.1s	remaining: 13s
# 791:	learn: 0.4511815	total: 49.1s	remaining: 12.9s
# 792:	learn: 0.4511594	total: 49.2s	remaining: 12.8s
# 793:	learn: 0.4511380	total: 49.2s	remaining: 12.8s
# 794:	learn: 0.4511101	total: 49.3s	remaining: 12.7s
# 795:	learn: 0.4510925	total: 49.3s	remaining: 12.6s
# 796:	learn: 0.4510749	total: 49.4s	remaining: 12.6s
# 797:	learn: 0.4510644	total: 49.4s	remaining: 12.5s
# 798:	learn: 0.4510539	total: 49.4s	remaining: 12.4s
# 799:	learn: 0.4510402	total: 49.5s	remaining: 12.4s
# 800:	learn: 0.4510211	total: 49.6s	remaining: 12.3s
# 801:	learn: 0.4510116	total: 49.6s	remaining: 12.3s
# 802:	learn: 0.4509946	total: 49.7s	remaining: 12.2s
# 803:	learn: 0.4509822	total: 49.8s	remaining: 12.1s
# 804:	learn: 0.4509758	total: 49.8s	remaining: 12.1s
# 805:	learn: 0.4509554	total: 49.9s	remaining: 12s
# 806:	learn: 0.4509383	total: 49.9s	remaining: 11.9s
# 807:	learn: 0.4509231	total: 50s	remaining: 11.9s
# 808:	learn: 0.4509128	total: 50.1s	remaining: 11.8s
# 809:	learn: 0.4508918	total: 50.1s	remaining: 11.8s
# 810:	learn: 0.4508797	total: 50.2s	remaining: 11.7s
# 811:	learn: 0.4508680	total: 50.3s	remaining: 11.6s
# 812:	learn: 0.4508496	total: 50.3s	remaining: 11.6s
# 813:	learn: 0.4508177	total: 50.4s	remaining: 11.5s
# 814:	learn: 0.4508027	total: 50.5s	remaining: 11.5s
# 815:	learn: 0.4507685	total: 50.5s	remaining: 11.4s
# 816:	learn: 0.4507518	total: 50.6s	remaining: 11.3s
# 817:	learn: 0.4507421	total: 50.7s	remaining: 11.3s
# 818:	learn: 0.4507129	total: 50.7s	remaining: 11.2s
# 819:	learn: 0.4506909	total: 50.8s	remaining: 11.1s
# 820:	learn: 0.4506780	total: 50.8s	remaining: 11.1s
# 821:	learn: 0.4506430	total: 50.9s	remaining: 11s
# 822:	learn: 0.4506183	total: 50.9s	remaining: 11s
# 823:	learn: 0.4506068	total: 51s	remaining: 10.9s
# 824:	learn: 0.4505835	total: 51s	remaining: 10.8s
# 825:	learn: 0.4505797	total: 51.1s	remaining: 10.8s
# 826:	learn: 0.4505755	total: 51.1s	remaining: 10.7s
# 827:	learn: 0.4505534	total: 51.2s	remaining: 10.6s
# 828:	learn: 0.4505080	total: 51.2s	remaining: 10.6s
# 829:	learn: 0.4504879	total: 51.3s	remaining: 10.5s
# 830:	learn: 0.4504659	total: 51.3s	remaining: 10.4s
# 831:	learn: 0.4504493	total: 51.4s	remaining: 10.4s
# 832:	learn: 0.4504268	total: 51.4s	remaining: 10.3s
# 833:	learn: 0.4504178	total: 51.5s	remaining: 10.3s
# 834:	learn: 0.4504152	total: 51.5s	remaining: 10.2s
# 835:	learn: 0.4503997	total: 51.6s	remaining: 10.1s
# 836:	learn: 0.4503816	total: 51.6s	remaining: 10s
# 837:	learn: 0.4503675	total: 51.6s	remaining: 9.98s
# 838:	learn: 0.4503391	total: 51.7s	remaining: 9.91s
# 839:	learn: 0.4503205	total: 51.7s	remaining: 9.84s
# 840:	learn: 0.4503056	total: 51.7s	remaining: 9.78s
# 841:	learn: 0.4502887	total: 51.7s	remaining: 9.71s
# 842:	learn: 0.4502462	total: 51.8s	remaining: 9.64s
# 843:	learn: 0.4502304	total: 51.8s	remaining: 9.57s
# 844:	learn: 0.4502126	total: 51.8s	remaining: 9.51s
# 845:	learn: 0.4501792	total: 51.9s	remaining: 9.44s
# 846:	learn: 0.4501744	total: 51.9s	remaining: 9.37s
# 847:	learn: 0.4501634	total: 51.9s	remaining: 9.3s
# 848:	learn: 0.4501462	total: 51.9s	remaining: 9.24s
# 849:	learn: 0.4501272	total: 52s	remaining: 9.17s
# 850:	learn: 0.4501149	total: 52s	remaining: 9.1s
# 851:	learn: 0.4500964	total: 52s	remaining: 9.04s
# 852:	learn: 0.4500749	total: 52.1s	remaining: 8.97s
# 853:	learn: 0.4500618	total: 52.1s	remaining: 8.9s
# 854:	learn: 0.4500527	total: 52.1s	remaining: 8.84s
# 855:	learn: 0.4500211	total: 52.1s	remaining: 8.77s
# 856:	learn: 0.4499784	total: 52.2s	remaining: 8.7s
# 857:	learn: 0.4499712	total: 52.2s	remaining: 8.64s
# 858:	learn: 0.4499628	total: 52.2s	remaining: 8.57s
# 859:	learn: 0.4499542	total: 52.3s	remaining: 8.51s
# 860:	learn: 0.4499367	total: 52.3s	remaining: 8.44s
# 861:	learn: 0.4499300	total: 52.3s	remaining: 8.37s
# 862:	learn: 0.4499109	total: 52.3s	remaining: 8.31s
# 863:	learn: 0.4498896	total: 52.4s	remaining: 8.24s
# 864:	learn: 0.4498753	total: 52.4s	remaining: 8.18s
# 865:	learn: 0.4498664	total: 52.4s	remaining: 8.11s
# 866:	learn: 0.4498590	total: 52.4s	remaining: 8.04s
# 867:	learn: 0.4498500	total: 52.5s	remaining: 7.98s
# 868:	learn: 0.4498226	total: 52.5s	remaining: 7.92s
# 869:	learn: 0.4498183	total: 52.5s	remaining: 7.85s
# 870:	learn: 0.4498111	total: 52.6s	remaining: 7.78s
# 871:	learn: 0.4497840	total: 52.6s	remaining: 7.72s
# 872:	learn: 0.4497559	total: 52.6s	remaining: 7.66s
# 873:	learn: 0.4497517	total: 52.7s	remaining: 7.59s
# 874:	learn: 0.4497410	total: 52.7s	remaining: 7.53s
# 875:	learn: 0.4497170	total: 52.7s	remaining: 7.46s
# 876:	learn: 0.4497106	total: 52.7s	remaining: 7.4s
# 877:	learn: 0.4497087	total: 52.8s	remaining: 7.33s
# 878:	learn: 0.4496803	total: 52.8s	remaining: 7.27s
# 879:	learn: 0.4496650	total: 52.8s	remaining: 7.2s
# 880:	learn: 0.4496392	total: 52.9s	remaining: 7.14s
# 881:	learn: 0.4496270	total: 52.9s	remaining: 7.08s
# 882:	learn: 0.4496070	total: 52.9s	remaining: 7.01s
# 883:	learn: 0.4495849	total: 52.9s	remaining: 6.95s
# 884:	learn: 0.4495821	total: 53s	remaining: 6.88s
# 885:	learn: 0.4495715	total: 53s	remaining: 6.82s
# 886:	learn: 0.4495619	total: 53s	remaining: 6.75s
# 887:	learn: 0.4495409	total: 53s	remaining: 6.69s
# 888:	learn: 0.4495252	total: 53.1s	remaining: 6.63s
# 889:	learn: 0.4495009	total: 53.1s	remaining: 6.56s
# 890:	learn: 0.4494954	total: 53.1s	remaining: 6.5s
# 891:	learn: 0.4494678	total: 53.2s	remaining: 6.44s
# 892:	learn: 0.4494598	total: 53.2s	remaining: 6.37s
# 893:	learn: 0.4494237	total: 53.2s	remaining: 6.31s
# 894:	learn: 0.4493887	total: 53.3s	remaining: 6.25s
# 895:	learn: 0.4493740	total: 53.3s	remaining: 6.18s
# 896:	learn: 0.4493368	total: 53.3s	remaining: 6.12s
# 897:	learn: 0.4493266	total: 53.3s	remaining: 6.06s
# 898:	learn: 0.4493098	total: 53.4s	remaining: 6s
# 899:	learn: 0.4492912	total: 53.4s	remaining: 5.93s
# 900:	learn: 0.4492840	total: 53.4s	remaining: 5.87s
# 901:	learn: 0.4492680	total: 53.4s	remaining: 5.81s
# 902:	learn: 0.4492659	total: 53.5s	remaining: 5.74s
# 903:	learn: 0.4492597	total: 53.5s	remaining: 5.68s
# 904:	learn: 0.4492318	total: 53.5s	remaining: 5.62s
# 905:	learn: 0.4492102	total: 53.6s	remaining: 5.56s
# 906:	learn: 0.4491807	total: 53.6s	remaining: 5.5s
# 907:	learn: 0.4491550	total: 53.6s	remaining: 5.43s
# 908:	learn: 0.4491538	total: 53.7s	remaining: 5.37s
# 909:	learn: 0.4491459	total: 53.7s	remaining: 5.31s
# 910:	learn: 0.4491331	total: 53.7s	remaining: 5.25s
# 911:	learn: 0.4491247	total: 53.7s	remaining: 5.18s
# 912:	learn: 0.4491062	total: 53.8s	remaining: 5.12s
# 913:	learn: 0.4490798	total: 53.8s	remaining: 5.06s
# 914:	learn: 0.4490773	total: 53.8s	remaining: 5s
# 915:	learn: 0.4490667	total: 53.9s	remaining: 4.94s
# 916:	learn: 0.4490408	total: 53.9s	remaining: 4.88s
# 917:	learn: 0.4490377	total: 53.9s	remaining: 4.82s
# 918:	learn: 0.4490215	total: 53.9s	remaining: 4.75s
# 919:	learn: 0.4489971	total: 54s	remaining: 4.69s
# 920:	learn: 0.4489803	total: 54s	remaining: 4.63s
# 921:	learn: 0.4489566	total: 54s	remaining: 4.57s
# 922:	learn: 0.4489374	total: 54.1s	remaining: 4.51s
# 923:	learn: 0.4489267	total: 54.1s	remaining: 4.45s
# 924:	learn: 0.4489204	total: 54.1s	remaining: 4.39s
# 925:	learn: 0.4489101	total: 54.1s	remaining: 4.33s
# 926:	learn: 0.4489000	total: 54.2s	remaining: 4.26s
# 927:	learn: 0.4488756	total: 54.2s	remaining: 4.2s
# 928:	learn: 0.4488620	total: 54.2s	remaining: 4.14s
# 929:	learn: 0.4488483	total: 54.2s	remaining: 4.08s
# 930:	learn: 0.4488354	total: 54.3s	remaining: 4.02s
# 931:	learn: 0.4488164	total: 54.3s	remaining: 3.96s
# 932:	learn: 0.4488012	total: 54.3s	remaining: 3.9s
# 933:	learn: 0.4487889	total: 54.4s	remaining: 3.84s
# 934:	learn: 0.4487734	total: 54.4s	remaining: 3.78s
# 935:	learn: 0.4487622	total: 54.4s	remaining: 3.72s
# 936:	learn: 0.4487508	total: 54.4s	remaining: 3.66s
# 937:	learn: 0.4487221	total: 54.5s	remaining: 3.6s
# 938:	learn: 0.4487165	total: 54.5s	remaining: 3.54s
# 939:	learn: 0.4486931	total: 54.5s	remaining: 3.48s
# 940:	learn: 0.4486614	total: 54.6s	remaining: 3.42s
# 941:	learn: 0.4486407	total: 54.6s	remaining: 3.36s
# 942:	learn: 0.4486177	total: 54.6s	remaining: 3.3s
# 943:	learn: 0.4486022	total: 54.7s	remaining: 3.24s
# 944:	learn: 0.4485972	total: 54.7s	remaining: 3.18s
# 945:	learn: 0.4485771	total: 54.7s	remaining: 3.12s
# 946:	learn: 0.4485669	total: 54.7s	remaining: 3.06s
# 947:	learn: 0.4485532	total: 54.8s	remaining: 3s
# 948:	learn: 0.4485262	total: 54.8s	remaining: 2.94s
# 949:	learn: 0.4485134	total: 54.8s	remaining: 2.88s
# 950:	learn: 0.4485014	total: 54.9s	remaining: 2.83s
# 951:	learn: 0.4484821	total: 54.9s	remaining: 2.77s
# 952:	learn: 0.4484708	total: 54.9s	remaining: 2.71s
# 953:	learn: 0.4484607	total: 54.9s	remaining: 2.65s
# 954:	learn: 0.4484504	total: 55s	remaining: 2.59s
# 955:	learn: 0.4484305	total: 55s	remaining: 2.53s
# 956:	learn: 0.4484176	total: 55s	remaining: 2.47s
# 957:	learn: 0.4484013	total: 55.1s	remaining: 2.41s
# 958:	learn: 0.4483766	total: 55.1s	remaining: 2.35s
# 959:	learn: 0.4483631	total: 55.1s	remaining: 2.3s
# 960:	learn: 0.4483516	total: 55.1s	remaining: 2.24s
# 961:	learn: 0.4483425	total: 55.2s	remaining: 2.18s
# 962:	learn: 0.4483314	total: 55.2s	remaining: 2.12s
# 963:	learn: 0.4483073	total: 55.2s	remaining: 2.06s
# 964:	learn: 0.4482795	total: 55.3s	remaining: 2s
# 965:	learn: 0.4482475	total: 55.3s	remaining: 1.95s
# 966:	learn: 0.4482424	total: 55.3s	remaining: 1.89s
# 967:	learn: 0.4482283	total: 55.4s	remaining: 1.83s
# 968:	learn: 0.4482145	total: 55.4s	remaining: 1.77s
# 969:	learn: 0.4482065	total: 55.4s	remaining: 1.71s
# 970:	learn: 0.4481921	total: 55.4s	remaining: 1.66s
# 971:	learn: 0.4481868	total: 55.5s	remaining: 1.6s
# 972:	learn: 0.4481792	total: 55.5s	remaining: 1.54s
# 973:	learn: 0.4481610	total: 55.5s	remaining: 1.48s
# 974:	learn: 0.4481390	total: 55.5s	remaining: 1.42s
# 975:	learn: 0.4481095	total: 55.6s	remaining: 1.37s
# 976:	learn: 0.4480883	total: 55.6s	remaining: 1.31s
# 977:	learn: 0.4480667	total: 55.6s	remaining: 1.25s
# 978:	learn: 0.4480526	total: 55.7s	remaining: 1.19s
# 979:	learn: 0.4480488	total: 55.7s	remaining: 1.14s
# 980:	learn: 0.4480499	total: 55.7s	remaining: 1.08s
# 981:	learn: 0.4480312	total: 55.8s	remaining: 1.02s
# 982:	learn: 0.4480181	total: 55.8s	remaining: 965ms
# 983:	learn: 0.4480085	total: 55.8s	remaining: 908ms
# 984:	learn: 0.4479975	total: 55.8s	remaining: 850ms
# 985:	learn: 0.4479753	total: 55.9s	remaining: 793ms
# 986:	learn: 0.4479613	total: 55.9s	remaining: 736ms
# 987:	learn: 0.4479475	total: 55.9s	remaining: 679ms
# 988:	learn: 0.4479290	total: 55.9s	remaining: 622ms
# 989:	learn: 0.4479175	total: 56s	remaining: 565ms
# 990:	learn: 0.4479045	total: 56s	remaining: 509ms
# 991:	learn: 0.4478839	total: 56s	remaining: 452ms
# 992:	learn: 0.4478582	total: 56.1s	remaining: 395ms
# 993:	learn: 0.4478508	total: 56.1s	remaining: 339ms
# 994:	learn: 0.4478481	total: 56.1s	remaining: 282ms
# 995:	learn: 0.4478377	total: 56.1s	remaining: 225ms
# 996:	learn: 0.4478351	total: 56.2s	remaining: 169ms
# 997:	learn: 0.4478193	total: 56.2s	remaining: 113ms
# 998:	learn: 0.4478077	total: 56.2s	remaining: 56.3ms
# 999:	learn: 0.4477998	total: 56.2s	remaining: 0us

# %% [markdown]
# Сделаем предсказания на тестовой выборке, сформируем из них рекомендации:
#
# будем рекомендовать пользователю статьи, для которых модель спрогнозировала наибольшую вероятность взаимодействия.

# %%
top_k = 10

predictions = model.predict_proba(test[interactions_train_df.columns[features_start:]])[:, 1]
test['predictions'] = predictions

test = test.sort_values('predictions', ascending=False)
predictions = test.groupby('personId')['contentId'].aggregate(list)
tmp_predictions = []

for personId in tqdm_notebook(interactions.index):
    prediction = np.array(predictions.loc[personId])

    tmp_predictions.append(
        list(prediction[~np.in1d(
            prediction,
            interactions.loc[personId, 'true_train'])])[:top_k])

interactions['prediction_content'] = tmp_predictions
# Out:
# <ipython-input-27-104d42c29fab>:10: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for personId in tqdm_notebook(interactions.index):
#   0%|          | 0/1112 [00:00<?, ?it/s]

# %% [markdown]
# Оценим их качество.

# %%
calc_precision('prediction_content')
# Out:
# 0.007337405374702384

# %% [markdown]
# ## Часть 3. Факторизационная машина

# %% [markdown]
# Вспомним, что факторизационная машина учитывает попарные взаимодействия признаков, что приводит сразу и к использованию контента (сами признаки), и к обучению скрытых представлений (индикаторы пользователей и статей).
#
# Попробуем факторизационные машины из библиотеки fastFM.

# %%
# !pip install fastFM
# Out:
# Collecting fastFM
#   Downloading fastFM-0.2.10.tar.gz (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 14.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from fastFM) (1.26.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from fastFM) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from fastFM) (1.13.1)
# Requirement already satisfied: cython in /usr/local/lib/python3.11/dist-packages (from fastFM) (3.0.12)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->fastFM) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->fastFM) (3.5.0)
# Building wheels for collected packages: fastFM
#   Building wheel for fastFM (setup.py) ... done
#   Created wheel for fastFM: filename=fastFM-0.2.10-cp311-cp311-linux_x86_64.whl size=625904 sha256=74d7f2e6b844870def90d1f8ef96ec1fb27c31a4c0f261dffe018ba67ca1dc7b
#   Stored in directory: /root/.cache/pip/wheels/2c/7e/87/e3b3c36cb0f43f6e583663f16e211a71ac0833090379911750
# Successfully built fastFM
# Installing collected packages: fastFM
# Successfully installed fastFM-0.2.10

# %%
from fastFM import als

# %% [markdown]
# Перейдём к обобщению матричных разложений — факторизационным машинам, которые могут работать с контентной информацией. Вспомним, какие данные у нас изначально были:

# %% [markdown]
# В факторизационную машину можно загрузить "айдишники" пользователей и статей (то есть сделать аналог коллаборативной фильтрации) и одновременно различные признаки.
#
# Удобно обрабатывать категориальные переменные (id и другие) можно с помощью DictVectorizer. Например, процесс может выглядеть вот так:
# ```python
# train = [
#     {"user": "1", "item": "5", "age": 19},
#     {"user": "2", "item": "43", "age": 33},
#     {"user": "3", "item": "20", "age": 55},
#     {"user": "4", "item": "10", "age": 20},
# ]
# v = DictVectorizer()
# X = v.fit_transform(train)
# y = np.repeat(1.0, X.shape[0])
# fm = als.FMRegression()
# fm.fit(X,y)
# fm.predict(v.transform({"user": "1", "item": "10", "age": 24}))
# ```

# %% [markdown]
# Сгенерируем таблицу с признаками в таком виде, где будут id пользователя, статьи и автора статьи и несколько признаков, которые вы сможете придумать.

# %%
train_data = []

for i in tqdm_notebook(range(len(interactions_train_df))):
    features = {}
    features['personId'] = str(interactions_train_df.iloc[i].personId)
    features['contentId'] = str(interactions_train_df.iloc[i].contentId)
    try:
        article = articles_df.loc[features['contentId']]
        features['authorId'] = str(article.authorPersonId)
        features['authorCountry'] = str(article.authorCountry)
        features['lang'] = str(article.lang)
    except:
        features['authorId'] = 'unknown'
        features['authorCountry'] = 'unknown'
        features['lang'] = 'unknown'

    train_data.append(features)
# Out:
# <ipython-input-36-8b108631fc4f>:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm_notebook(range(len(interactions_train_df))):
#   0%|          | 0/146645 [00:00<?, ?it/s]

# %% [markdown]
# Повторим эту процедуру для тестовой выборки. Заметим, что модель оценивает каждую пару потенциального взаимодействия, а значит, надо подготовить выборку из всех возможных пар из пользователей и статей.

# %%
test_data = []

for i in tqdm_notebook(range(len(interactions))):
    features = {}
    features['personId'] = str(interactions.index[i])
    for j in range(len(ratings.columns)):
        features['contentId'] = str(ratings.columns[j])

        try:
            article = articles_df.loc[features['contentId']]
            features['authorId'] = str(article.authorPersonId)
            features['authorCountry'] = str(article.authorCountry)
            features['lang'] = str(article.lang)
        except:
            features['authorId'] = 'unknown'
            features['authorCountry'] = 'unknown'
            features['lang'] = 'unknown'

        test_data.append(deepcopy(features))
# Out:
# <ipython-input-37-b631575303ef>:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm_notebook(range(len(interactions))):
#   0%|          | 0/1112 [00:00<?, ?it/s]

# %% [markdown]
# Векторизуем, получим разреженные матрицы.
#
# Мы будем обучать регрессор на силу взаимодействия, а для него нужны отрицательные примеры. Добавим некоторое количество случайных примеров как негативные (матрица взаимодействий разреженная, поэтому шансы взять как негативное взаимодействие некоторое положительное мало).

# %%
dv = DictVectorizer()

train_features = dv.fit_transform(
    train_data + list(np.random.permutation(test_data)[:100000]))
test_features = dv.transform(test_data)

# %%
train_features
# Out:
# <246645x3481 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1233225 stored elements in Compressed Sparse Row format>

# %%
y_train = np.array(list(interactions_train_df.eventStrength.values) + list(np.zeros(100000)))

# %% [markdown]
# ### Гиперпараметры регрессии в fastFM

# %% [markdown]
# ![fastFM.png](data:image/png;base64,...)

# %%
# Инициализация и обучение модели
fm = als.FMRegression(n_iter=30, rank=10, l2_reg_w=0.1, l2_reg_V=0.5)
fm.fit(train_features, y_train)

# Предсказания
y_predict = fm.predict(test_features)
new_ratings = y_predict.reshape((len(interactions), len(ratings.columns)))

# Формирование рекомендаций
predictions = []

top_k = 10
for i, person in enumerate(interactions.index):
    user_prediction = ratings.columns[np.argsort(new_ratings[i])[::-1]]
    predictions.append(user_prediction[~np.in1d(user_prediction, interactions.loc[person, 'true_train'])][:top_k])

interactions['fm_prediction'] = predictions

# %%
calc_precision('fm_prediction')
# Out:
# 0.006460368606568671
